# %% [markdown]
# The Standard and Poor's (S&P) 500 Index is an collection of the 500 largest market capped public companies in the US and is a very popular investment tool for the general public, with an average return of approximately 10% year over year. As a result, many traders try to "beat the market" by trading individual companies in the hopes of gaining returns greater than the S&P 500. In this project, we will see if the popular comedy TV Show "South Park" can help traders beat the S&P 500 by trading the companies that are mentioned in the shows' episodes.

# %% [markdown]
# The first step in this project is to create a list of publicly traded companies as well as their ticker symbols and the most relevant Wikipedia link for each company. That way, we can compare the Wikipedia links of every entry in the show to this list.
#
# We will get the list of publicly traded companies from the Nasdaq website.

# %%
import pandas as pd
import wikipedia
import time
# #We'll want to automate this instead of manually downloading and reading the csv. The website is https://www.nasdaq.com/market-activity/stocks/screener
# stocks = pd.read_csv("nasdaq_screener_1661885402576.csv")
# #Keep only company ticker and name
# stocks = stocks[["Symbol","Name"]]
# stocks['Name'] = stocks['Name'].str.replace('Common Stock', '')

# %%
# wikilinks = []
# for company in stocks["Name"]:
#     try:
#         wikilinks.append(wikipedia.page(title = company, auto_suggest = False).url)
#     except:
#         wikilinks.append("None")
# wikilinks

# %%
# # stocks1 = stocks.head()
# # stocks1['Name'] = stocks1['Name'].str.replace('Common Stock', '')
# # wikilinks = []
# # for company in stocks1["Name"]:
# #     try:
# #         wikilinks.append(wikipedia.page(title = company, auto_suggest = False).url)
# #     except:
# #         wikilinks.append("None")
# # wikilinks
# stocks["Wikilink"] = wikilinks
# #Only keep relevant companies
# stocks = stocks[stocks.Wikilink != "None"]

# %%
from bs4 import BeautifulSoup
import requests
url = "https://en.wikipedia.org/wiki/List_of_South_Park_episodes"
page = requests.get(url)
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of South Park episodes - Wikipedia</title>
# <script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"d53369d9-e678-42e2-a01c-36b934c51bce","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_South_Park_episodes","wgTitle":"List of South Park episodes","wgCurRevisionId":1105579636,"wgRevisionId":1105579636,"wgArticleId":224267,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Pages containing links to subscription-only content","All articles with dead external links","Articles with dead external links from December 2017","Articles with permanently dead external links","Articles with short description",
# "Short description is different from Wikidata","Wikipedia indefinitely semi-protected pages","Use mdy dates from January 2017","Official website not in Wikidata","South Park episodes","South Park lists","Lists of American adult animated television series episodes","Lists of American sitcom episodes"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"List_of_South_Park_episodes","wgRelevantArticleId":224267,"wgIsProbablyEditable":false,"wgRelevantPageIsProbablyEditable":false,"wgRestrictionEdit":["autoconfirmed"],"wgRestrictionMove":["autoconfirmed"],"wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":false},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":40000,"wgNoticeProject":"wikipedia","wgVector2022PreviewPages":[],"wgMediaViewerOnClick":true,
# "wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":10,"wgULSCurrentAutonym":"English","wgEditSubmitButtonLabelPublish":true,"wgCentralAuthMobileDomain":false,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":true,"wgWikibaseItemId":"Q1540084","GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":false,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.styles.legacy":"ready","jquery.makeCollapsible.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.wikimediaBadges":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","jquery.makeCollapsible","skins.vector.legacy.js","mmv.head","mmv.bootstrap.autostart",
# "ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.cx.eventlogging.campaigns","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","ext.popups","ext.uls.compactlinks","ext.uls.interface","ext.growthExperiments.SuggestedEditSession"];</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@12s5i",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});});});</script>
# <link href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
# <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector"></script>
# <meta content="" name="ResourceLoaderDynamicStyles"/>
# <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
# <meta content="MediaWiki 1.39.0-wmf.27" name="generator"/>
# <meta content="origin" name="referrer"/>
# <meta content="origin-when-crossorigin" name="referrer"/>
# <meta content="origin-when-cross-origin" name="referrer"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/f/ff/South_park_sign.svg/1200px-South_park_sign.svg.png" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="1429" property="og:image:height"/>
# <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/f/ff/South_park_sign.svg/800px-South_park_sign.svg.png" property="og:image"/>
# <meta content="800" property="og:image:width"/>
# <meta content="953" property="og:image:height"/>
# <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/f/ff/South_park_sign.svg/640px-South_park_sign.svg.png" property="og:image"/>
# <meta content="640" property="og:image:width"/>
# <meta content="762" property="og:image:height"/>
# <meta content="width=1000" name="viewport"/>
# <meta content="List of South Park episodes - Wikipedia" property="og:title"/>
# <meta content="website" property="og:type"/>
# <link href="//upload.wikimedia.org" rel="preconnect"/>
# <link href="//en.m.wikipedia.org/wiki/List_of_South_Park_episodes" media="only screen and (max-width: 720px)" rel="alternate"/>
# <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
# <link href="/static/favicon/wikipedia.ico" rel="icon"/>
# <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
# <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
# <link href="https://creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
# <link href="https://en.wikipedia.org/wiki/List_of_South_Park_episodes" rel="canonical"/>
# <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
# <link href="//login.wikimedia.org" rel="dns-prefetch"/>
# </head>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-List_of_South_Park_episodes rootpage-List_of_South_Park_episodes skin-vector action-view skin-vector-legacy"><div class="noprint" id="mw-page-base"></div>
# <div class="noprint" id="mw-head-base"></div>
# <div class="mw-body" id="content" role="main">
# <a id="top"></a>
# <div id="siteNotice"><!-- CentralNotice --></div>
# <div class="mw-indicators">
# <div class="mw-indicator" id="mw-indicator-pp-default"><div class="mw-parser-output"><a href="/wiki/Wikipedia:Protection_policy#semi" title="This article is semi-protected."><img alt="Page semi-protected" data-file-height="512" data-file-width="512" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/30px-Semi-protection-shackle.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/40px-Semi-protection-shackle.svg.png 2x" width="20"/></a></div></div>
# </div>
# <h1 class="firstHeading mw-first-heading" id="firstHeading">List of <i>South Park</i> episodes</h1>
# <div class="vector-body" id="bodyContent">
# <div class="noprint" id="siteSub">From Wikipedia, the free encyclopedia</div>
# <div id="contentSub"></div>
# <div id="contentSub2"></div>
# <div id="jump-to-nav"></div>
# <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>
# <a class="mw-jump-link" href="#searchInput">Jump to search</a>
# <div class="mw-body-content mw-content-ltr" dir="ltr" id="mw-content-text" lang="en"><div class="mw-parser-output"><p class="mw-empty-elt">
# </p><p class="mw-empty-elt">
# </p>
# <div class="floatright"><a class="image" href="/wiki/File:South_park_sign.svg"><img alt="South park sign.svg" data-file-height="561" data-file-width="471" decoding="async" height="262" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/ff/South_park_sign.svg/220px-South_park_sign.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/ff/South_park_sign.svg/330px-South_park_sign.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/ff/South_park_sign.svg/440px-South_park_sign.svg.png 2x" width="220"/></a></div>
# <p><i><a href="/wiki/South_Park" title="South Park">South Park</a></i> is an American <a class="mw-redirect" href="/wiki/Animated" title="Animated">animated</a> television <a href="/wiki/Sitcom" title="Sitcom">sitcom</a> created by <a href="/wiki/Trey_Parker" title="Trey Parker">Trey Parker</a> and <a href="/wiki/Matt_Stone" title="Matt Stone">Matt Stone</a> for <a href="/wiki/Comedy_Central" title="Comedy Central">Comedy Central</a>.<sup class="reference" id="cite_ref-'South_Park'_Falls_Flatulent_1-0"><a href="#cite_note-'South_Park'_Falls_Flatulent-1">[1]</a></sup> The series came from a pair of animated shorts titled <i><a class="mw-redirect" href="/wiki/The_Spirit_of_Christmas_(short_film)" title="The Spirit of Christmas (short film)">The Spirit of Christmas</a></i>, and was originally developed for the <a href="/wiki/Fox_Broadcasting_Company" title="Fox Broadcasting Company">Fox Broadcasting Company</a>. Eventually, Fox refused to air the show, which was later picked up by Comedy Central. The first episode of <i>South Park</i> aired on Comedy Central on August 13, 1997. Intended for mature audiences, the show has become infamous for its crude language and <a class="mw-redirect" href="/wiki/Dark_humor" title="Dark humor">dark</a>, <a class="mw-redirect" href="/wiki/Surreal_humor" title="Surreal humor">surreal humor</a> that <a href="/wiki/Satire" title="Satire">lampoons</a> a <a href="/wiki/Subject_matter_in_South_Park" title="Subject matter in South Park">wide range of topics</a>. The story revolves around four boys—<a href="/wiki/Stan_Marsh" title="Stan Marsh">Stan Marsh</a>, <a href="/wiki/Kyle_Broflovski" title="Kyle Broflovski">Kyle Broflovski</a>, <a href="/wiki/Eric_Cartman" title="Eric Cartman">Eric Cartman</a>, and <a href="/wiki/Kenny_McCormick" title="Kenny McCormick">Kenny McCormick</a>—and their bizarre adventures in and around the eponymous Colorado town.
# </p><p>Episodes of <i>South Park</i> have been nominated for a variety of different awards, including three <a class="mw-redirect" href="/wiki/Annie_Award" title="Annie Award">Annie Awards</a> (with one win),<sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup><sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup> two <a class="mw-redirect" href="/wiki/Critics%27_Choice_Television_Award" title="Critics' Choice Television Award">Critics' Choice Television Award</a> (with no wins),<sup class="reference" id="cite_ref-4"><a href="#cite_note-4">[4]</a></sup><sup class="reference" id="cite_ref-5"><a href="#cite_note-5">[5]</a></sup> 17 <a class="mw-redirect" href="/wiki/Emmy_Award" title="Emmy Award">Emmy Awards</a> (with five wins),<sup class="reference" id="cite_ref-6"><a href="#cite_note-6">[6]</a></sup> 3 <a href="/wiki/TCA_Awards" title="TCA Awards">TCA Awards</a> (with no wins),<sup class="reference" id="cite_ref-7"><a href="#cite_note-7">[7]</a></sup><sup class="reference" id="cite_ref-8"><a href="#cite_note-8">[8]</a></sup> and received a <a class="mw-redirect" href="/wiki/Peabody_Award" title="Peabody Award">Peabody Award</a>.<sup class="reference" id="cite_ref-9"><a href="#cite_note-9">[9]</a></sup> The first twenty-three seasons have been released on DVD and <a href="/wiki/Blu-ray" title="Blu-ray">Blu-ray</a>, in addition to several compilation DVDs.<sup class="reference" id="cite_ref-10"><a href="#cite_note-10">[10]</a></sup><sup class="reference" id="cite_ref-11"><a href="#cite_note-11">[11]</a></sup><sup class="reference" id="cite_ref-order_explanation_12-0"><a href="#cite_note-order_explanation-12">[12]</a></sup><sup class="reference" id="cite_ref-17premiere_13-0"><a href="#cite_note-17premiere-13">[13]</a></sup>
# </p><p>On September 12, 2019, the show was renewed up to the 26th season.<sup class="reference" id="cite_ref-14"><a href="#cite_note-14">[14]</a></sup> On August 5, 2021, Comedy Central announced that Parker and Stone signed a $900 million deal for extending the series to 30 seasons through 2027 and 14 feature films, exclusive to the <a href="/wiki/Paramount%2B" title="Paramount+">Paramount+</a> streaming platform owned and operated by Comedy Central's parent company, ViacomCBS, which would become <a href="/wiki/Paramount_Global" title="Paramount Global">Paramount Global</a>. Two films were confirmed to be released at the end of 2021,<sup class="reference" id="cite_ref-15"><a href="#cite_note-15">[15]</a></sup><sup class="reference" id="cite_ref-16"><a href="#cite_note-16">[16]</a></sup> which Parker and Stone later indicated would be <a class="mw-redirect" href="/wiki/Made-for-TV_movie" title="Made-for-TV movie">made-for-TV movies</a>.<sup class="reference" id="cite_ref-17"><a href="#cite_note-17">[17]</a></sup> Because those films continue storylines from the episodic series, and bear production codes that align with the series episodes, they are considered to be episodes as well as films.
# <br/>
# </p>
# <style data-mw-deduplicate="TemplateStyles:r1097603156">.mw-parser-output .horizontal-toc-align-right{float:right}.mw-parser-output .horizontal-toc-align-left{float:left}.mw-parser-output .horizontal-toc-align-center{clear:none}.mw-parser-output .horizontal-toc-align-center .toc{margin-left:auto;margin-right:auto}.mw-parser-output .horizontal-toc-clear-right{clear:right}.mw-parser-output .horizontal-toc-clear-left{clear:left}.mw-parser-output .horizontal-toc-clear-both{clear:both}.mw-parser-output .horizontal-toc-clear-none{clear:none}</style><div class="horizontal-toc horizontal-toc-clear-left"><div aria-labelledby="toc-title-text" class="toc plainlinks" id="toc" role="navigation">
# <div class="hlist hlist-separated">
# <dl><dt>Seasons</dt>
# <dd><a href="#Season_1_(1997–98)">1</a></dd>
# <dd><a href="#Season_2_(1998–99)">2</a></dd>
# <dd><a href="#Season_3_(1999–2000)">3</a></dd>
# <dd><a href="#Season_4_(2000)">4</a></dd>
# <dd><a href="#Season_5_(2001)">5</a></dd>
# <dd><a href="#Season_6_(2002)">6</a></dd>
# <dd><a href="#Season_7_(2003)">7</a></dd>
# <dd><a href="#Season_8_(2004)">8</a></dd>
# <dd><a href="#Season_9_(2005)">9</a></dd>
# <dd><a href="#Season_10_(2006)">10</a></dd>
# <dd><a href="#Season_11_(2007)">11</a></dd>
# <dd><a href="#Season_12_(2008)">12</a></dd>
# <dd><a href="#Season_13_(2009)">13</a></dd>
# <dd><a href="#Season_14_(2010)">14</a></dd>
# <dd><a href="#Season_15_(2011)">15</a></dd>
# <dd><a href="#Season_16_(2012)">16</a></dd>
# <dd><a href="#Season_17_(2013)">17</a></dd>
# <dd><a href="#Season_18_(2014)">18</a></dd>
# <dd><a href="#Season_19_(2015)">19</a></dd>
# <dd><a href="#Season_20_(2016)">20</a></dd>
# <dd><a href="#Season_21_(2017)">21</a></dd>
# <dd><a href="#Season_22_(2018)">22</a></dd>
# <dd><a href="#Season_23_(2019)">23</a></dd>
# <dd><a href="#Season_24_(2020–21)">24</a></dd>
# <dd><a href="#Season_25_(2022)">25</a></dd></dl>
# <ul><li><a href="#Home_media">Home media</a></li>
# <li><a href="#References">References</a></li></ul>
# </div>
# </div></div>
# <h2><span class="mw-headline" id="Series_overview">Series overview</span></h2>
# <table class="wikitable plainrowheaders" style="text-align:center;height:1px;display:table"><tbody><tr style="text-align:center"><th rowspan="2" scope="col" style="min-width:50px;padding:0 8px">Season</th><th colspan="2" rowspan="2" scope="col" style="padding:0 8px">Episodes</th><th colspan="3" scope="col">Originally aired</th></tr><tr><th scope="col">First aired</th><th scope="col">Last aired</th><th scope="col" style="padding:0 8px">Network</th></tr><tr style="height:100%"><th colspan="1" scope="row" style="height:inherit;padding:0"><span style="text-align:center;float:left;width:100%;height:100%"><span style="width:14px;background:#5B5856;height:100%;float:left;box-shadow:inset -1px 0 #A2A9B1"></span><span style="height:100%;width:calc(100% - 14px);display:flex;vertical-align:middle;align-items:center;justify-content:center"><span class="nowrap"><a href="#Season_1_(1997–98)">1</a></span></span></span></th><td colspan="2">13</td><td colspan="1" style="padding:0.2em 0.4em">August 13, 1997<span style="display:none"> (<span class="bday dtstart published updated">1997-08-13</span>)</span></td><td style="padding:0 8px">February 25, 1998<span style="display:none"> (<span class="dtend">1998-02-25</span>)</span></td><td rowspan="24"><a href="/wiki/Comedy_Central" title="Comedy Central">Comedy Central</a></td></tr><tr style="height:100%"><th colspan="1" scope="row" style="height:inherit;padding:0"><span style="text-align:center;float:left;width:100%;height:100%"><span style="width:14px;background:#AF181F;height:100%;float:left;box-shadow:inset -1px 0 #A2A9B1"></span><span style="height:100%;width:calc(100% - 14px);display:flex;vertical-align:middle;align-items:center;justify-content:center"><span class="nowrap"><a href="#Season_2_(1998–99)">2</a></span></span></span></th><td colspan="2">18</td><td colspan="1" style="padding:0.2em 0.4em">April 1, 1998<span style="display:none"> (<span class="bday dtstart published updated">1998-04-01</span>)</span></td><td style="padding:0 8px">January 20, 1999<span style="display:none"> (<span class="dtend">1999-01-20</span>)</span></td></tr><tr style="height:100%"><th colspan="1" scope="row" style="height:inherit;padding:0"><span style="text-align:center;float:left;width:100%;height:100%"><span style="width:14px;background:#016363;height:100%;float:left;box-shadow:inset -1px 0 #A2A9B1"></span><span style="height:100%;width:calc(100% - 14px);display:flex;vertical-align:middle;align-items:center;justify-content:center"><span class="nowrap"><a href="#Season_3_(1999–2000)">3</a></span></span></span></th><td colspan="2">17</td><td colspan="1" style="padding:0.2em 0.4em">April 7, 1999<span style="display:none"> (<span class="bday dtstart published updated">1999-04-07</span>)</span></td><td style="padding:0 8px">January 12, 2000<span style="display:none"> (<span class="dtend">2000-01-12</span>)</span></td></tr><tr style="height:100%"><th colspan="1" scope="row" style="height:inherit;padding:0"><span style="text-align:center;float:left;width:100%;height:100%"><span style="width:14px;background:#4B0082;height:100%;float:left;box-shadow:inset -1px 0 #A2A9B1"></span><span style="height:100%;width:calc(100% - 14px);display:flex;vertical-align:middle;align-items:center;justify-content:center"><span class="nowrap"><a href="#Season_4_(2000)">4</a></span></span></span></th><td colspan="2">17</td><td colspan="1" style="padding:0.2em 0.4em">April 5, 2000<span style="display:none"> (<span class="bday dtstart published updated">2000-04-05</span>)</span></td><td style="padding:0 8px">December 20, 2000<span style="display:none"> (<span class="dtend">2000-12-20</span>)</span></td></tr><tr style="height:100%"><th colspan="1" scope="row" style="height:inherit;padding:0"><span style="text-align:center;float:left;width:100%;height:100%"><span style="width:14px;background:#FFCC00;height:100%;float:left;box-shadow:inset -1px 0 #A2A9B1"></span><span style="height:100%;width:calc(100% - 14px);display:flex;vertical-align:middle;al ...
# <p><style data-mw-deduplicate="TemplateStyles:r1041539562">.mw-parser-output .citation{word-wrap:break-word}.mw-parser-output .citation:target{background-color:rgba(0,127,255,0.133)}</style><span class="citation wikicite" id="endnote_1"><b><a href="#ref_1">^Note 1</a></b></span> These Paramount+ specials do not have a production code and are not considered part of the regular season
# </p>
# <h2><span class="mw-headline" id="Episodes">Episodes</span></h2>
# <h3><span id="Season_1_.281997.E2.80.9398.29"></span><span class="mw-headline" id="Season_1_(1997–98)">Season 1 (1997–98)</span></h3>
# <style data-mw-deduplicate="TemplateStyles:r1033289096">.mw-parser-output .hatnote{font-style:italic}.mw-parser-output div.hatnote{padding-left:1.6em;margin-bottom:0.5em}.mw-parser-output .hatnote i{font-style:normal}.mw-parser-output .hatnote+link+.hatnote{margin-top:-0.5em}</style><div class="hatnote navigation-not-searchable" role="note">Main article: <a href="/wiki/South_Park_(season_1)" title="South Park (season 1)">South Park (season 1)</a></div>
# <table class="wikitable plainrowheaders wikiepisodetable" style="width:100%"><tbody><tr style="color:white;text-align:center"><th scope="col" style="background:#5B5856;width:5%"><abbr title="Number">No.</abbr><br/>overall</th><th scope="col" style="background:#5B5856;width:5%"><abbr title="Number">No.</abbr> in<br/>season</th><th scope="col" style="background:#5B5856;width:21%">Title</th><th scope="col" style="background:#5B5856;width:17%">Directed by</th><th scope="col" style="background:#5B5856;width:17%">Written by</th><th scope="col" style="background:#5B5856;width:16%">Original air date <span style="background-color:white;padding:1px;display:inline-block;line-height:50%"><sup class="reference" id="cite_ref-tvguide_s01_18-0"><a href="#cite_note-tvguide_s01-18">[18]</a></sup></span></th><th scope="col" style="background:#5B5856;width:7%"><abbr title="Production">Prod.</abbr><br/>code</th><th scope="col" style="background:#5B5856;width:11%">US viewers<br/>(millions)</th></tr><tr class="vevent" style="text-align:center;background:inherit"><th id="ep1" rowspan="1" scope="row" style="text-align:center">1</th><td style="text-align:center">1</td><td class="summary" style="text-align:left">"<a href="/wiki/Cartman_Gets_an_Anal_Probe" title="Cartman Gets an Anal Probe">Cartman Gets an Anal Probe</a>"</td><td style="text-align:center"><a href="/wiki/Trey_Parker" title="Trey Parker">Trey Parker</a><sup class="reference" id="cite_ref-Far-out_19-0"><a href="#cite_note-Far-out-19">[19]</a></sup></td><td style="text-align:center">Trey Parker &amp; <a href="/wiki/Matt_Stone" title="Matt Stone">Matt Stone</a></td><td style="text-align:center">August 13, 1997<span style="display:none"> (<span class="bday dtstart published updated">1997-08-13</span>)</span></td><td id="pc101" style="text-align:center">101</td><td style="text-align:center">0.98<sup class="reference" id="cite_ref-bc68_20-0"><a href="#cite_note-bc68-20">[20]</a></sup></td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep2" rowspan="1" scope="row" style="text-align:center">2</th><td style="text-align:center">2</td><td class="summary" style="text-align:left">"<a href="/wiki/Weight_Gain_4000" title="Weight Gain 4000">Weight Gain 4000</a>"</td><td style="text-align:center">Trey Parker &amp; Matt Stone</td><td style="text-align:center">Trey Parker &amp; Matt Stone</td><td style="text-align:center">August 20, 1997<span style="display:none"> (<span class="bday dtstart published updated">1997-08-20</span>)</span></td><td id="pc102" style="text-align:center">102</td><td style="text-align:center">1.2<sup class="reference" id="cite_ref-bc68_20-1"><a href="#cite_note-bc68-20">[20]</a></sup></td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep3" rowspan="1" scope="row" style="text-align:center">3</th><td style="text-align:center">3</td><td class="summary" style="text-align:left">"<a href="/wiki/Volcano_(South_Park)" title="Volcano (South Park)">Volcano</a>"</td><td style="text-align:center">Trey Parker &amp; Matt Stone</td><td style="text-align:center">Trey Parker &amp; Matt Stone</td><td style="text-align:center">August 27, 1997<span style="display:none"> (<span class="bday dtstart published updated">1997-08-27</span>)</span></td><td id="pc103" style="text-align:center">103</td><td style="text-align:center">1.0<sup class="reference" id="cite_ref-bc68_20-2"><a href="#cite_note-bc68-20">[20]</a></sup></td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep4" rowspan="1" scope="row" style="text-align:center">4</th><td style="text-align:center">4</td><td class="summary" style="text-align:left">"<a href="/wiki/Big_Gay_Al%27s_Big_Gay_Boat_Ride" title="Big Gay Al's Big Gay Boat Ride">Big Gay Al's Big Gay Boat Ride</a>"</td><td style="text-align:center">Trey Parker<sup class="reference" id="cite_ref-emmy1998_21-0"><a href="#cite_note-emmy1998-21">[21]</a></sup></td><td style="text-align:center">Trey Parker &amp; Matt Stone<sup class="reference" id="cite_ref-emmy1998_21-1"><a href="#cite_note-emmy1998-21">[21]</a></sup></td><td style="text-align:center">September 3, 1997<span style="display:none"> (<span class="bday dtstart published updated">1997-09-03</span>)</span></td><td id="pc104" style="text-align:center">104</td><td style="text-align:center">1.5<sup class="reference" id="cite_ref-bc68_20-3"><a href="#cite_note-bc68-20">[20]</a></sup></td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep5" rowspan="1" scope="row" style="text-align:center">5</th><td style="text-align:center">5</td><td class="summary" style="text-align:left">"<a href="/wiki/An_Elephant_Makes_Love_to_a_Pig" title="An Elephant Makes Love to a Pig">An Elephant Makes Love to a Pig</a>"</td><td style="text-align:center">Trey Parker <small>(uncredited)</small></td><td style="text-align:center">Trey Parker, Matt Stone &amp; <a href="/wiki/Dan_Sterling" title="Dan Sterling">Dan Sterling</a></td><td style="text-align:center">September 10, 1997<span style="display:none"> (<span class="bday dtstart published updated">1997-09-10</span>)</span></td><td id="pc105" style="text-align:center">105</td><td style="text-align:center">1.8<sup class="reference" id="cite_ref-bc68_20-4"><a href="#cite_note-bc68-20">[20]</a></sup></td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep6" rowspan="1" scope="row" style="text-align:center">6</th><td style="text-align:center">6</td><td class="summary" style="text-align:left">"<a href="/wiki/Death_(South_Park)" title="Death (South Park)">Death</a>"</td><td style="text-align:center">Matt Stone</td><td style="text-align:center">Trey Parker &amp; Matt Stone</td><td style="text-align:center">September 17, 1997<span style="display:none"> (<span class="bday dtstart published updated">1997-09-17</span>)</span></td><td id="pc106" style="text-align:center">106</td><td style="text-align:center">1.3<sup class="reference" id="cite_ref-bc68_20-5"><a href="#cite_note-bc68-20">[20]</a></sup></td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep7" rowspan="1" scope="row" style="text-align:center">7</th><td style="text-align:center">7</td><td class="summary" style="text-align:left">"<a href="/wiki/Pinkeye_(South_Park)" title="Pinkeye (South Park)">Pinkeye</a>"</td><td style="text-align:center">Trey Parker &amp; Matt Stone</td><td style="text-align:center">Trey Parker, Matt Stone &amp; <a href="/wiki/Philip_Stark" title="Philip Stark">Philip Stark</a></td><td style="text-align:center">October 29, 1997<span style="display:none"> (<span class="bday dtstart published updated">1997-10-29</span>)</span></td><td id="pc107" style="text-align:center">107</td><td style="text-align:center">2.7<sup class="reference" id="cite_ref-22"><a href="#cite_note-22">[22]</a></sup></td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep8" rowspan="1" scope="row" style="text-align:center">8</th><td style="text-align:center">8</td><td class="summary" style="text-align:left">"<a href="/wiki/Starvin%27_Marvin" title="Starvin' Marvin">Starvin' Marvin</a>"</td><td style="text-align:center">Trey Parker</td><td style="text-align:center">Trey Parker</td><td style="text-align:center">November 19, 1997<span style="display:none"> (<span class="bday dtstart published updated">1997-11-19</span>)</span></td><td id="pc109" style="text-align:center">109</td><td style="text-align:center">2.2<sup class="reference" id="cite_ref-23"><a href="#cite_note-23">[23]</a></sup></td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep9" rowspan="1" scope="row" style="text-align:center">9</th><td style="text-align:center">9</td><td class="summary" style="text-align:left">"<a href="/wiki/Mr._Hankey,_the_Christmas_Poo" title="Mr. Hankey, the Christmas Poo">Mr. Hankey, the Christmas Poo</a>"</td><td style="text-align:center">Trey Parker &amp; Matt Stone</td><td style="text-align:center">Trey Parker</td><td style="text-align:center">December 17, 1997<span style="display:none"> (<span class="bday dtstart published updated">1997-12-17</span>)</span></td><td id="pc110" style="text-align:center">110</td><td style="text-align:center">4.5<sup class="reference" id="cite_ref-24"><a href="#cite_note-24">[24]</a></sup></td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep10" rowspan="1" scope="row" style="text-align:center">10</th><td style="text-align:center">10</td><td class="summary" style="text-align:left">"<a href="/wiki/Damien_(South_Park)" title="Damien (South Park)">Damien</a>"</td><td style="text-align:center">Trey Parker</td><td style="text-align:center">Trey Parker &amp; Matt Stone</td><td style="text-align:center">February 4, 1998<span style="display:none"> (<span class="bday dtstart published updated">1998-02-04</span>)</span></td><td id="pc108" style="text-align:center">108</td><td style="text-align:center">5.1<sup class="reference" id="cite_ref-mecha_25-0"><a href="#cite_note-mecha-25">[25]</a></sup><sup class="reference" id="cite_ref-McCabeJanet_26-0"><a href="#cite_note-McCabeJanet-26">[26]</a></sup></td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep11" rowspan="1" scope="row" style="text-align:center">11</th><td style="text-align:center">11</td><td class="summary" style="text-align:left">"<a href="/wiki/Tom%27s_Rhinoplasty" title="Tom's Rhinoplasty">Tom's Rhinoplasty</a>"</td><td style="text-align:center">Trey Parker <small>(uncredited)</small></td><td style="text-align:center">Trey Parker</td><td style="text-align:center">February 11, 1998<span style="display:none"> (<span class="bday dtstart published updated">1998-02-11</span>)</span></td><td id="pc111" style="text-align:center">111</td><td style="text-align:center">4.1<sup class="reference" id="cite_ref-27"><a href="#cite_note-27">[27]</a></sup></td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep12" rowspan="1" scope="row" style="text-align:center">12</th><td style="text-align:center">12</td><td class="summary" style="text-align:left">"<a href="/wiki/Mecha-Streisand" title="Mecha-Streisand">Mecha-Streisand</a>"</td><td style="text-align:center">Trey Parker</td><td style="text-align:center">Trey Parker, Philip Stark &amp; Matt Stone</td><td style="text-align:center">February 18, 1998<span style="display:none"> (<span class="bday dtstart published updated">1998-02-18</span>)</span></td><td id="pc112" style="text-align:center">112</td><td style="text-align:center">5.4<sup class="reference" id="cite_ref-28"><a href="#cite_note-28">[28]</a></sup></td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep13" rowspan="1" scope="row" style="text-align:center">13</th><td style="text-align:center">13</td><td class="summary" style="text-align:left">"<a href="/wiki/Cartman%27s_Mom_Is_a_Dirty_Slut" title="Cartman's Mom Is a Dirty Slut">Cartman's Mom Is a Dirty Slut</a>"</td><td style="text-align:center">Trey Parker</td><td style="text-align:center">Trey Parker &amp; David R. Goodman</td><td style="text-align:center">February 25, 1998<span style="display:none"> (<span class="bday dtstart published updated">1998-02-25</span>)</span></td><td id="pc113" style="text-align:center">113</td><td style="text-align:center">6.4<sup class="reference" id="cite_ref-29"><a href="#cite_note-29">[29]</a></sup></td></tr></tbody></table>
# <h3><span id="Season_2_.281998.E2.80.9399.29"></span><span class="mw-headline" id="Season_2_(1998–99)">Season 2 (1998–99)</span></h3>
# <link href="mw-data:TemplateStyles:r1033289096" rel="mw-deduplicated-inline-style"/><div class="hatnote navigation-not-searchable" role="note">Main article: <a href="/wiki/South_Park_(season_2)" title="South Park (season 2)">South Park (season 2)</a></div>
# <table class="wikitable plainrowheaders wikiepisodetable" style="width:100%"><tbody><tr style="color:white;text-align:center"><th scope="col" style="background:#AF181F;width:5%"><abbr title="Number">No.</abbr><br/>overall</th><th scope="col" style="background:#AF181F;width:5%"><abbr title="Number">No.</abbr> in<br/>season</th><th scope="col" style="background:#AF181F;width:22%">Title</th><th scope="col" style="background:#AF181F;width:19%">Directed by</th><th scope="col" style="background:#AF181F;width:19%">Written by</th><th scope="col" style="background:#AF181F;width:18%">Original air date <span style="background-color:white;padding:1px;display:inline-block;line-height:50%"><sup class="reference" id="cite_ref-tvguide_s02_30-0"><a href="#cite_note-tvguide_s02-30">[30]</a></sup></span></th><th scope="col" style="background:#AF181F;width:8%"><abbr title="Production">Prod.</abbr><br/>code</th></tr><tr class="vevent" style="text-align:center;background:inherit"><th id="ep14" rowspan="1" scope="row" style="text-align:center">14</th><td style="text-align:center">1</td><td class="summary" style="text-align:left">"<a href="/wiki/Terrance_and_Phillip_in_Not_Without_My_Anus" title="Terrance and Phillip in Not Without My Anus">Terrance and Phillip in Not Without My Anus</a>"</td><td style="text-align:center"><a href="/wiki/Trey_Parker" title="Trey Parker">Trey Parker</a></td><td style="text-align:center">Trisha Nixon &amp; Trey Parker</td><td style="text-align:center">April 1, 1998<span style="display:none"> (<span class="bday dtstart published updated">1998-04-01</span>)</span></td><td id="pc201" style="text-align:center">201</td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep15" rowspan="1" scope="row" style="text-align:center">15</th><td style="text-align:center">2</td><td class="summary" style="text-align:left">"<a href="/wiki/Cartman%27s_Mom_Is_Still_a_Dirty_Slut" title="Cartman's Mom Is Still a Dirty Slut">Cartman's Mom Is Still a Dirty Slut</a>"</td><td style="text-align:center">Trey Parker</td><td style="text-align:center">David Goodman &amp; Trey Parker</td><td style="text-align:center">April 22, 1998<span style="display:none"> (<span class="bday dtstart published updated">1998-04-22</span>)</span></td><td id="pc202" style="text-align:center">202</td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep16" rowspan="1" scope="row" style="text-align:center">16</th><td style="text-align:center">3</td><td class="summary" style="text-align:left">"<a href="/wiki/Ike%27s_Wee_Wee" title="Ike's Wee Wee">Ike's Wee Wee</a>"</td><td style="text-align:center">Trey Parker</td><td style="text-align:center">Trey Parker</td><td style="text-align:center">May 20, 1998<span style="display:none"> (<span class="bday dtstart published updated">1998-05-20</span>)</span></td><td id="pc204" style="text-align:center">204</td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep17" rowspan="1" scope="row" style="text-align:center">17</th><td style="text-align:center">4</td><td class="summary" style="text-align:left">"<a href="/wiki/Chickenlover" title="Chickenlover">Chickenlover</a>"</td><td style="text-align:center">Trey Parker</td><td style="text-align:center">Trey Parker, <a href="/wiki/Matt_Stone" title="Matt Stone">Matt Stone</a> &amp; David Goodman</td><td style="text-align:center">May 27, 1998<span style="display:none"> (<span class="bday dtstart published updated">1998-05-27</span>)</span></td><td id="pc203" style="text-align:center">203</td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep18" rowspan="1" scope="row" style="text-align:center">18</th><td style="text-align:center">5</td><td class="summary" style="text-align:left">"<a href="/wiki/Conjoined_Fetus_Lady" title="Conjoined Fetus Lady">Conjoined Fetus Lady</a>"</td><td style="text-align:center">Trey Parker</td><td style="text-align:center">Trey Parker, Matt Stone &amp; David Goodman</td><td style="text-align:center">June 3, 1998<span style="display:none"> (<span class="bday dtstart published updated">1998-06-03</span>)</span></td><td id="pc205" style="text-align:center">205</td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep19" rowspan="1" scope="row" style="text-align:center">19</th><td style="text-align:center">6</td><td class="summary" style="text-align:left">"<a href="/wiki/The_Mexican_Staring_Frog_of_Southern_Sri_Lanka" title="The Mexican Staring Frog of Southern Sri Lanka">The Mexican Staring Frog of Southern Sri Lanka</a>"</td><td style="text-align:center">Trey Parker</td><td style="text-align:center">Trey Parker &amp; Matt Stone</td><td style="text-align:center">June 10, 1998<span style="display:none"> (<span class="bday dtstart published updated">1998-06-10</span>)</span></td><td id="pc206" style="text-align:center">206</td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep20" rowspan="1" scope="row" style="text-align:center">20</th><td style="text-align:center">7</td><td class="summary" style="text-align:left">"<a href="/wiki/City_on_the_Edge_of_Forever_(South_Park)" title="City on the Edge of Forever (South Park)">City on the Edge of Forever</a>"<br/>"Flashbacks"</td><td style="text-align:center">Trey Parker</td><td style="text-align:center">Trey Parker &amp; <a href="/wiki/Nancy_Pimental" title="Nancy Pimental">Nancy M. Pimental</a></td><td style="text-align:center">June 17, 1998<span style="display:none"> (<span class="bday dtstart published updated">1998-06-17</span>)</span></td><td id="pc207" style="text-align:center">207</td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep21" rowspan="1" scope="row" style="text-align:center">21</th><td style="text-align:center">8</td><td class="summary" style="text-align:left">"<a href="/wiki/Summer_Sucks" title="Summer Sucks">Summer Sucks</a>"</td><td style="text-align:center">Trey Parker</td><td style="text-align:center">Nancy M. Pimental &amp; Trey Parker</td><td style="text-align:center">June 24, 1998<span style="display:none"> (<span class="bday dtstart published updated">1998-06-24</span>)</span></td><td id="pc208" style="text-align:center">208</td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep22" rowspan="1" scope="row" style="text-align:center">22</th><td style="text-align:center">9</td><td class="summary" style="text-align:left">"<a href="/wiki/Chef%27s_Chocolate_Salty_Balls" title="Chef's Chocolate Salty Balls">Chef's Chocolate Salty Balls</a>"</td><td style="text-align:center">Trey Parker</td><td style="text-align:center">Trey Parker, Matt Stone &amp; Nancy M. Pimental</td><td style="text-align:center">August 19, 1998<span style="display:none"> (<span class="bday dtstart published updated">1998-08-19</span>)</span></td><td id="pc209" style="text-align:center">209</td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep23" rowspan="1" scope="row" style="text-align:center">23</th><td style="text-align:center">10</td><td class="summary" style="text-align:left">"<a href="/wiki/Chickenpox_(South_Park)" title="Chickenpox (South Park)">Chickenpox</a>"</td><td style="text-align:center">Trey Parker</td><td style="text-align:center">Trey Parker, Matt Stone &amp; Trisha Nixon</td><td style="text-align:center">August 26, 1998<span style="display:none"> (<span class="bday dtstart published updated">1998-08-26</span>)</span></td><td id="pc210" style="text-align:center">210</td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep24" rowspan="1" scope="row" style="text-align:center">24</th><td style="text-align:center">11</td><td class="summary" style="text-align:left">"<a href="/wiki/Roger_Ebert_Should_Lay_Off_the_Fatty_Foods" title="Roger Ebert Should Lay Off the Fatty Foods">Roger Ebert Should Lay Off the Fatty Foods</a>"</td><td style="text-align:center">Trey Parker</td><td style="text-align:center">Trey Parker &amp; David Goodman</td><td style="text-align:center">September 2, 1998<span style="display:none"> (<span class="bday dtstart published updated">1998-09-02</span>)</span></td><td id="pc211" style="text-align:center">211</td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep25" rowspan="1" scope="row" style="text-align:center">25</th><td style="text-align:center">12</td><td class="summary" style="text-align:left">"<a href="/wiki/Clubhouses_(South_Park)" title="Clubhouses (South Park)">Clubhouses</a>"</td><td style="text-align:center">Trey Parker</td><td style="text-align:center">Trey Parker &amp; Nancy M. Pimental</td><td style="text-align:center">September 23, 1998<span style="display:none"> (<span class="bday dtstart published updated">1998-09-23</span>)</span></td><td id="pc212" style="text-align:center">212</td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep26" rowspan="1" scope="row" style="text-align:center">26</th><td style="text-align:center">13</td><td class="summary" style="text-align:left">"<a href="/wiki/Cow_Days" title="Cow Days">Cow Days</a>"</td><td style="text-align:center">Trey Parker</td><td style="text-align:center">Trey Parker &amp; David Goodman</td><td style="text-align:center">September 30, 1998<span style="display:none"> (<span class="bday dtstart published updated">1998-09-30</span>)</span></td><td id="pc213" style="text-align:center">213</td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep27" rowspan="1" scope="row" style="text-align:center">27</th><td style="text-align:center">14</td><td class="summary" style="text-align:left">"<a href="/wiki/Chef_Aid" title="Chef Aid">Chef Aid</a>"</td><td style="text-align:center">Trey Parker</td><td style="text-align:center">Trey Parker &amp; Matt Stone</td><td style="text-align:center">October 7, 1998<span style="display:none"> (<span class="bday dtstart published updated">1998-10-07</span>)</span></td><td id="pc214" style="text-align:center">214</td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep28" rowspan="1" scope="row" style="text-align:center">28</th><td style="text-align:center">15</td><td class="summary" style="text-align:left">"<a href="/wiki/Spookyfish" title="Spookyfish">Spookyfish</a>"</td><td style="text-align:center">Trey Parker</td><td style="text-align:center">Trey Parker</td><td style="text-align:center">October 28, 1998<span style="display:none"> (<span class="bday dtstart published updated">1998-10-28</span>)</span></td><td id="pc215" style="text-align:center">215</td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep29" rowspan="1" scope="row" style="text-align:center">29</th><td style="text-align:center">16</td><td class="summary" style="text-align:left">"<a href="/wiki/Merry_Christmas,_Charlie_Manson!" title="Merry Christmas, Charlie Manson!">Merry Christmas, Charlie Manson!</a>"</td><td style="text-align:center"><a href="/wiki/Eric_Stough" title="Eric Stough">Eric Stough</a></td><td style="text-align:center">Trey Parker &amp; Nancy M. Pimental</td><td style="text-align:center">December 9, 1998<span style="display:none"> (<span class="bday dtstart published updated">1998-12-09</span>)</span></td><td id="pc216" style="text-align:center">216</td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep30" rowspan="1" scope="row" style="text-align:center">30</th><td style="text-align:center">17</td><td class="summary" style="text-align:left">"<a href="/wiki/Gnomes_(South_Park)" title="Gnomes (South Park)">Gnomes</a>"</td><td style="text-align:center">Trey Parker</td><td style="text-align:center"><a href="/wiki/Pam_Brady" title="Pam Brady">Pam Brady</a>, Trey Parker &amp; Matt Stone</td><td style="text-align:center">December 16, 1998<span style="display:none"> (<span class="bday dtstart published updated">1998-12-16</span>)</span></td><td id="pc217" style="text-align:center">217</td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep31" rowspan="1" scope="row" style="text-align:center">31</th><td style="text-align:center">18</td><td class="summary" style="text-align:left">"<a href="/wiki/Prehistoric_Ice_Man" title="Prehistoric Ice Man">Prehistoric Ice Man</a>"</td><td style="text-align:center">Eric Stough</td><td style="text-align:center">Trey Parker &amp; Nancy M. Pimental</td><td style="text-align:center">January 20, 1999<span style="display:none"> (<span class="bday dtstart published updated">1999-01-20</span>)</span></td><td id="pc218" style="text-align:center">218</td></tr></tbody></table>
# <h3><span id="Season_3_.281999.E2.80.932000.29"></span><span class="mw-headline" id="Season_3_(1999–2000)">Season 3 (1999–2000)</span></h3>
# <link href="mw-data:TemplateStyles:r1033289096" rel="mw-deduplicated-inline-style"/><div class="hatnote navigation-not-searchable" role="note">Main article: <a href="/wiki/South_Park_(season_3)" title="South Park (season 3)">South Park (season 3)</a></div>
# <table class="wikitable plainrowheaders wikiepisodetable" style="width:100%"><tbody><tr style="color:white;text-align:center"><th scope="col" style="background:#016363;width:5%"><abbr title="Number">No.</abbr><br/>overall</th><th scope="col" style="background:#016363;width:5%"><abbr title="Number">No.</abbr> in<br/>season</th><th scope="col" style="background:#016363;width:22%">Title</th><th scope="col" style="background:#016363;width:19%">Directed by</th><th scope="col" style="background:#016363;width:19%">Written by</th><th scope="col" style="background:#016363;width:18%">Original air date <span style="background-color:white;padding:1px;display:inline-block;line-height:50%"><sup class="reference" id="cite_ref-31"><a href="#cite_note-31">[31]</a></sup></span></th><th scope="col" style="background:#016363;width:8%"><abbr title="Production">Prod.</abbr><br/>code</th></tr><tr class="vevent" style="text-align:center;background:inherit"><th id="ep32" rowspan="1" scope="row" style="text-align:center">32</th><td style="text-align:center">1</td><td class="summary" style="text-align:left">"<a href="/wiki/Rainforest_Shmainforest" title="Rainforest Shmainforest">Rainforest Shmainforest</a>"</td><td style="text-align:center"><a href="/wiki/Trey_Parker" title="Trey Parker">Trey Parker</a> &amp; <a href="/wiki/Eric_Stough" title="Eric Stough">Eric Stough</a></td><td style="text-align:center">Trey Parker &amp; <a href="/wiki/Matt_Stone" title="Matt Stone">Matt Stone</a></td><td style="text-align:center">April 7, 1999<span style="display:none"> (<span class="bday dtstart published updated">1999-04-07</span>)</span></td><td id="pc301" style="text-align:center">301</td></tr>
# <tr class="vevent" style="text-align:center;background:inherit"><th id="ep33" rowspan="1" scope="row" style="text-align:center">33</th><td style="text-align:center">2</td><td class="summary" style="text-align:left">"<a href="/wiki/Spontaneous_Combustion_(South_Park)" title="Spontaneous Combustion (South Park)">Spontaneous Combustion</a>"</td><td style="text-align:center">Matt Stone</td><td style="text-align:center">Trey Parker, Matt Stone &amp; David Goodman</td><td style="text-align:center">April 14, 1999<span style="display:none"> (<span class="bday dtstart published updated">1999-04-14</span>)</span></td><td id="pc302" style="text-align:center">302</td></tr>
# ...
# </div>
# </nav>
# <nav aria-labelledby="p-interaction-label" class="vector-menu mw-portlet mw-portlet-interaction vector-menu-portal portal" id="p-interaction" role="navigation">
# <h3 class="vector-menu-heading" id="p-interaction-label">
# <span class="vector-menu-heading-label">Contribute</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="mw-list-item" id="n-help"><a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia"><span>Help</span></a></li><li class="mw-list-item" id="n-introduction"><a href="/wiki/Help:Introduction" title="Learn how to edit Wikipedia"><span>Learn to edit</span></a></li><li class="mw-list-item" id="n-portal"><a href="/wiki/Wikipedia:Community_portal" title="The hub for editors"><span>Community portal</span></a></li><li class="mw-list-item" id="n-recentchanges"><a accesskey="r" href="/wiki/Special:RecentChanges" title="A list of recent changes to Wikipedia [r]"><span>Recent changes</span></a></li><li class="mw-list-item" id="n-upload"><a href="/wiki/Wikipedia:File_Upload_Wizard" title="Add images or other media for use on Wikipedia"><span>Upload file</span></a></li></ul>
# </div>
# </nav>
# <nav aria-labelledby="p-tb-label" class="vector-menu mw-portlet mw-portlet-tb vector-menu-portal portal" id="p-tb" role="navigation">
# <h3 class="vector-menu-heading" id="p-tb-label">
# <span class="vector-menu-heading-label">Tools</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="mw-list-item" id="t-whatlinkshere"><a accesskey="j" href="/wiki/Special:WhatLinksHere/List_of_South_Park_episodes" title="List of all English Wikipedia pages containing links to this page [j]"><span>What links here</span></a></li><li class="mw-list-item" id="t-recentchangeslinked"><a accesskey="k" href="/wiki/Special:RecentChangesLinked/List_of_South_Park_episodes" rel="nofollow" title="Recent changes in pages linked from this page [k]"><span>Related changes</span></a></li><li class="mw-list-item" id="t-upload"><a accesskey="u" href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]"><span>Upload file</span></a></li><li class="mw-list-item" id="t-specialpages"><a accesskey="q" href="/wiki/Special:SpecialPages" title="A list of all special pages [q]"><span>Special pages</span></a></li><li class="mw-list-item" id="t-permalink"><a href="/w/index.php?title=List_of_South_Park_episodes&amp;oldid=1105579636" title="Permanent link to this revision of this page"><span>Permanent link</span></a></li><li class="mw-list-item" id="t-info"><a href="/w/index.php?title=List_of_South_Park_episodes&amp;action=info" title="More information about this page"><span>Page information</span></a></li><li class="mw-list-item" id="t-cite"><a href="/w/index.php?title=Special:CiteThisPage&amp;page=List_of_South_Park_episodes&amp;id=1105579636&amp;wpFormIdentifier=titleform" title="Information on how to cite this page"><span>Cite this page</span></a></li><li class="mw-list-item" id="t-wikibase"><a accesskey="g" href="https://www.wikidata.org/wiki/Special:EntityPage/Q1540084" title="Structured data on this page hosted by Wikidata [g]"><span>Wikidata item</span></a></li></ul>
# </div>
# </nav>
# <nav aria-labelledby="p-coll-print_export-label" class="vector-menu mw-portlet mw-portlet-coll-print_export vector-menu-portal portal" id="p-coll-print_export" role="navigation">
# <h3 class="vector-menu-heading" id="p-coll-print_export-label">
# <span class="vector-menu-heading-label">Print/export</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="mw-list-item" id="coll-download-as-rl"><a href="/w/index.php?title=Special:DownloadAsPdf&amp;page=List_of_South_Park_episodes&amp;action=show-download-screen" title="Download this page as a PDF file"><span>Download as PDF</span></a></li><li class="mw-list-item" id="t-print"><a accesskey="p" href="/w/index.php?title=List_of_South_Park_episodes&amp;printable=yes" title="Printable version of this page [p]"><span>Printable version</span></a></li></ul>
# </div>
# </nav>
# <nav aria-labelledby="p-lang-label" class="vector-menu mw-portlet mw-portlet-lang vector-menu-portal portal" id="p-lang" role="navigation">
# <h3 class="vector-menu-heading" id="p-lang-label">
# <span class="vector-menu-heading-label">Languages</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="interlanguage-link interwiki-be mw-list-item"><a class="interlanguage-link-target" href="https://be.wikipedia.org/wiki/%D0%A1%D0%BF%D1%96%D1%81_%D1%81%D0%B5%D1%80%D1%8B%D0%B9_South_Park" hreflang="be" lang="be" title="Спіс серый South Park – Belarusian"><span>Беларуская</span></a></li><li class="interlanguage-link interwiki-bg mw-list-item"><a class="interlanguage-link-target" href="https://bg.wikipedia.org/wiki/%D0%A1%D0%BF%D0%B8%D1%81%D1%8A%D0%BA_%D1%81_%D0%B5%D0%BF%D0%B8%D0%B7%D0%BE%D0%B4%D0%B8_%D0%BD%D0%B0_%D0%A1%D0%B0%D1%83%D1%82_%D0%9F%D0%B0%D1%80%D0%BA" hreflang="bg" lang="bg" title="Списък с епизоди на Саут Парк – Bulgarian"><span>Български</span></a></li><li class="interlanguage-link interwiki-cs mw-list-item"><a class="interlanguage-link-target" href="https://cs.wikipedia.org/wiki/Seznam_d%C3%ADl%C5%AF_seri%C3%A1lu_M%C4%9Bste%C4%8Dko_South_Park" hreflang="cs" lang="cs" title="Seznam dílů seriálu Městečko South Park – Czech"><span>Čeština</span></a></li><li class="interlanguage-link interwiki-da mw-list-item"><a class="interlanguage-link-target" href="https://da.wikipedia.org/wiki/Afsnit_af_South_Park" hreflang="da" lang="da" title="Afsnit af South Park – Danish"><span>Dansk</span></a></li><li class="interlanguage-link interwiki-de mw-list-item"><a class="interlanguage-link-target" href="https://de.wikipedia.org/wiki/South_Park/Episodenliste" hreflang="de" lang="de" title="South Park/Episodenliste – German"><span>Deutsch</span></a></li><li class="interlanguage-link interwiki-es mw-list-item"><a class="interlanguage-link-target" href="https://es.wikipedia.org/wiki/Anexo:Episodios_de_South_Park" hreflang="es" lang="es" title="Anexo:Episodios de South Park – Spanish"><span>Español</span></a></li><li class="interlanguage-link interwiki-eo mw-list-item"><a class="interlanguage-link-target" href="https://eo.wikipedia.org/wiki/South_Park#Epizodoj" hreflang="eo" lang="eo" title="South Park – Esperanto"><span>Esperanto</span></a></li><li class="interlanguage-link interwiki-fr mw-list-item"><a class="interlanguage-link-target" href="https://fr.wikipedia.org/wiki/Liste_des_%C3%A9pisodes_de_South_Park" hreflang="fr" lang="fr" title="Liste des épisodes de South Park – French"><span>Français</span></a></li><li class="interlanguage-link interwiki-ga mw-list-item"><a class="interlanguage-link-target" href="https://ga.wikipedia.org/wiki/Liosta_eipeas%C3%B3id%C3%AD_South_Park" hreflang="ga" lang="ga" title="Liosta eipeasóidí South Park – Irish"><span>Gaeilge</span></a></li><li class="interlanguage-link interwiki-ko mw-list-item"><a class="interlanguage-link-target" href="https://ko.wikipedia.org/wiki/%EC%82%AC%EC%9A%B0%EC%8A%A4_%ED%8C%8C%ED%81%AC%EC%9D%98_%EC%97%90%ED%94%BC%EC%86%8C%EB%93%9C_%EB%AA%A9%EB%A1%9D" hreflang="ko" lang="ko" title="사우스 파크의 에피소드 목록 – Korean"><span>한국어</span></a></li><li class="interlanguage-link interwiki-id mw-list-item"><a class="interlanguage-link-target" href="https://id.wikipedia.org/wiki/Daftar_episode_South_Park" hreflang="id" lang="id" title="Daftar episode South Park – Indonesian"><span>Bahasa Indonesia</span></a></li><li class="interlanguage-link interwiki-it mw-list-item"><a class="interlanguage-link-target" href="https://it.wikipedia.org/wiki/Episodi_di_South_Park" hreflang="it" lang="it" title="Episodi di South Park – Italian"><span>Italiano</span></a></li><li class="interlanguage-link interwiki-lv mw-list-item"><a class="interlanguage-link-target" href="https://lv.wikipedia.org/wiki/Dienvidparka_s%C4%93riju_saraksts" hreflang="lv" lang="lv" title="Dienvidparka sēriju saraksts – Latvian"><span>Latviešu</span></a></li><li class="interlanguage-link interwiki-hu mw-list-item"><a class="interlanguage-link-target" href="https://hu.wikipedia.org/wiki/A_South_Park_epiz%C3%B3djainak_list%C3%A1ja" hreflang="hu" lang="hu" title="A South Park epizódjainak listája – Hungarian"><span>Magyar</span></a></li><li class="interlanguage-link interwiki-ms mw-list-item">< ...
# <div class="after-portlet after-portlet-lang"><span class="wb-langlinks-edit wb-langlinks-link"><a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q1540084#sitelinks-wikipedia" title="Edit interlanguage links">Edit links</a></span></div>
# </div>
# </nav>
# </div>
# </div>
# <footer class="mw-footer" id="footer" role="contentinfo">
# <ul id="footer-info">
# <li id="footer-info-lastmod"> This page was last edited on 20 August 2022, at 21:52<span class="anonymous-show"> (UTC)</span>.</li>
# <li id="footer-info-copyright">Text is available under the <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License" rel="license">Creative Commons Attribution-ShareAlike License 3.0</a><a href="//creativecommons.org/licenses/by-sa/3.0/" rel="license" style="display:none;"></a>;
# additional terms may apply.  By using this site, you agree to the <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//foundation.wikimedia.org/wiki/Privacy_policy">Privacy Policy</a>. Wikipedia® is a registered trademark of the <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>
# </ul>
# <ul id="footer-places">
# <li id="footer-places-privacy"><a href="https://foundation.wikimedia.org/wiki/Privacy_policy">Privacy policy</a></li>
# <li id="footer-places-about"><a href="/wiki/Wikipedia:About">About Wikipedia</a></li>
# <li id="footer-places-disclaimer"><a href="/wiki/Wikipedia:General_disclaimer">Disclaimers</a></li>
# <li id="footer-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>
# <li id="footer-places-mobileview"><a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=List_of_South_Park_episodes&amp;mobileaction=toggle_view_mobile">Mobile view</a></li>
# <li id="footer-places-developers"><a href="https://developer.wikimedia.org">Developers</a></li>
# <li id="footer-places-statslink"><a href="https://stats.wikimedia.org/#/en.wikipedia.org">Statistics</a></li>
# <li id="footer-places-cookiestatement"><a href="https://foundation.wikimedia.org/wiki/Cookie_statement">Cookie statement</a></li>
# </ul>
# <ul class="noprint" id="footer-icons">
# <li id="footer-copyrightico"><a href="https://wikimediafoundation.org/"><img alt="Wikimedia Foundation" height="31" loading="lazy" src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88"/></a></li>
# <li id="footer-poweredbyico"><a href="https://www.mediawiki.org/"><img alt="Powered by MediaWiki" height="31" loading="lazy" src="/static/images/footer/poweredby_mediawiki_88x31.png" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" width="88"/></a></li>
# </ul>
# </footer>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"3.916","walltime":"4.206","ppvisitednodes":{"value":62520,"limit":1000000},"postexpandincludesize":{"value":1774368,"limit":2097152},"templateargumentsize":{"value":17615,"limit":2097152},"expansiondepth":{"value":20,"limit":100},"expensivefunctioncount":{"value":30,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":831541,"limit":5000000},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00% 3537.634      1 -total"," 43.91% 1553.373      2 Template:Reflist"," 35.92% 1270.622     26 Template:Episode_table"," 35.02% 1238.852    238 Template:Cite_web"," 32.20% 1138.971    319 Template:Episode_list/sublist"," 10.22%  361.426    347 Template:Start_date","  5.35%  189.101    373 Template:MONTHNAME","  5.31%  187.791      1 Template:Series_overview","  4.82%  170.388      1 South_Park_(season_1)","  3.42%  120.940    373 Template:MONTHNUMBER"]},"scribunto":{"limitreport-timeusage":{"value":"2.092","limit":"10.000"},"limitreport-memusage":{"value":25839176,"limit":52428800},"limitreport-profile":[["MediaWiki\\Extension\\Scribunto\\Engines\\LuaSandbox\\LuaSandboxCallback::getExpandedArgument","580","21.5"],["?","460","17.0"],["dataWrapper \u003Cmw.lua:669\u003E","240","8.9"],["MediaWiki\\Extension\\Scribunto\\Engines\\LuaSandbox\\LuaSandboxCallback::callParserFunction","140","5.2"],["MediaWiki\\Extension\\Scribunto\\Engines\\LuaSandbox\\LuaSandboxCallback::expandTemplate","120","4.4"],["\u003Cmw.lua:691\u003E","100","3.7"],["MediaWiki\\Extension\\Scribunto\\Engines\\LuaSandbox\\LuaSandboxCallback::gsub","100","3.7"],["MediaWiki\\Extension\\Scribunto\\Engines\\LuaSandbox\\LuaSandboxCallback::match","100","3.7"],["recursiveClone \u003CmwInit.lua:41\u003E","100","3.7"],["MediaWiki\\Extension\\Scribunto\\Engines\\LuaSandbox\\LuaSandboxCallback::getAllExpandedArguments","80","3.0"],["[others]","680","25.2"]]},"cachereport":{"origin":"mw1429","timestamp":"20220905191535","ttl":1814400,"transientcontent":false}}});});</script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"Article","name":"List of South Park episodes","url":"https:\/\/en.wikipedia.org\/wiki\/List_of_South_Park_episodes","sameAs":"http:\/\/www.wikidata.org\/entity\/Q1540084","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q1540084","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2003-05-10T00:51:35Z","dateModified":"2022-08-20T21:52:44Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/f\/ff\/South_park_sign.svg","headline":"Wikimedia list article"}</script><script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"Article","name":"List of South Park episodes","url":"https:\/\/en.wikipedia.org\/wiki\/List_of_South_Park_episodes","sameAs":"http:\/\/www.wikidata.org\/entity\/Q1540084","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q1540084","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2003-05-10T00:51:35Z","dateModified":"2022-08-20T21:52:44Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/f\/ff\/South_park_sign.svg","headline":"Wikimedia list article"}</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":113,"wgHostname":"mw1415"});});</script>
# </body>
# </html>

# %% [markdown]
# From the above HTML code, we see that the tables we are interested in are listed under the table class = "wikitable plainrowheaders wikiepisodetable". Each row that lists an episode is under the tr class = "vevent". Finally, under each of these rows, the air dates of the episodes is formatted as YYYY-MM-DD under the span class = "bday dtstart published updated".

# %%
epi = {}
epitracker = 1
for table in soup.find_all("table", class_ = "wikitable plainrowheaders wikiepisodetable"):
    for row in table.find_all("tr", class_ = "vevent"):
        epi[epitracker]={"date": row.find("span", class_ = "bday dtstart published updated").contents[0],
               "id": row.find("th").attrs["id"],
               "wikiLink": row.find("a", href = True, title = True).attrs["href"],
               "title": row.find("a", href = True, title = True).attrs["title"]}
        #epitracker=epitracker+1
        epitracker+=1
epi
# Out:
# {1: {'date': '1997-08-13',
#   'id': 'ep1',
#   'wikiLink': '/wiki/Cartman_Gets_an_Anal_Probe',
#   'title': 'Cartman Gets an Anal Probe'},
#  2: {'date': '1997-08-20',
#   'id': 'ep2',
#   'wikiLink': '/wiki/Weight_Gain_4000',
#   'title': 'Weight Gain 4000'},
#  3: {'date': '1997-08-27',
#   'id': 'ep3',
#   'wikiLink': '/wiki/Volcano_(South_Park)',
#   'title': 'Volcano (South Park)'},
#  4: {'date': '1997-09-03',
#   'id': 'ep4',
#   'wikiLink': '/wiki/Big_Gay_Al%27s_Big_Gay_Boat_Ride',
#   'title': "Big Gay Al's Big Gay Boat Ride"},
#  5: {'date': '1997-09-10',
#   'id': 'ep5',
#   'wikiLink': '/wiki/An_Elephant_Makes_Love_to_a_Pig',
#   'title': 'An Elephant Makes Love to a Pig'},
#  6: {'date': '1997-09-17',
#   'id': 'ep6',
#   'wikiLink': '/wiki/Death_(South_Park)',
#   'title': 'Death (South Park)'},
#  7: {'date': '1997-10-29',
#   'id': 'ep7',
#   'wikiLink': '/wiki/Pinkeye_(South_Park)',
#   'title': 'Pinkeye (South Park)'},
#  8: {'date': '1997-11-19',
#   'id': 'ep8',
#   'wikiLink': '/wiki/Starvin%27_Marvin',
#   'title': "Starvin' Marvin"},
#  9: {'date': '1997-12-17',
#   'id': 'ep9',
#   'wikiLink': '/wiki/Mr._Hankey,_the_Christmas_Poo',
#   'title': 'Mr. Hankey, the Christmas Poo'},
#  10: {'date': '1998-02-04',
#   'id': 'ep10',
#   'wikiLink': '/wiki/Damien_(South_Park)',
#   'title': 'Damien (South Park)'},
#  11: {'date': '1998-02-11',
#   'id': 'ep11',
#   'wikiLink': '/wiki/Tom%27s_Rhinoplasty',
#   'title': "Tom's Rhinoplasty"},
#  12: {'date': '1998-02-18',
#   'id': 'ep12',
#   'wikiLink': '/wiki/Mecha-Streisand',
#   'title': 'Mecha-Streisand'},
#  13: {'date': '1998-02-25',
#   'id': 'ep13',
#   'wikiLink': '/wiki/Cartman%27s_Mom_Is_a_Dirty_Slut',
#   'title': "Cartman's Mom Is a Dirty Slut"},
#  14: {'date': '1998-04-01',
#   'id': 'ep14',
#   'wikiLink': '/wiki/Terrance_and_Phillip_in_Not_Without_My_Anus',
#   'title': 'Terrance and Phillip in Not Without My Anus'},
#  15: {'date': '1998-04-22',
#   'id': 'ep15',
#   'wikiLink': '/wiki/Cartman%27s_Mom_Is_Still_a_Dirty_Slut',
#   'title': "Cartman's Mom Is Still a Dirty Slut"},
#  16: {'date': '1998-05-20',
#   'id': 'ep16',
#   'wikiLink': '/wiki/Ike%27s_Wee_Wee',
#   'title': "Ike's Wee Wee"},
#  17: {'date': '1998-05-27',
#   'id': 'ep17',
#   'wikiLink': '/wiki/Chickenlover',
#   'title': 'Chickenlover'},
#  18: {'date': '1998-06-03',
#   'id': 'ep18',
#   'wikiLink': '/wiki/Conjoined_Fetus_Lady',
#   'title': 'Conjoined Fetus Lady'},
#  19: {'date': '1998-06-10',
#   'id': 'ep19',
#   'wikiLink': '/wiki/The_Mexican_Staring_Frog_of_Southern_Sri_Lanka',
#   'title': 'The Mexican Staring Frog of Southern Sri Lanka'},
#  20: {'date': '1998-06-17',
#   'id': 'ep20',
#   'wikiLink': '/wiki/City_on_the_Edge_of_Forever_(South_Park)',
#   'title': 'City on the Edge of Forever (South Park)'},
#  21: {'date': '1998-06-24',
#   'id': 'ep21',
#   'wikiLink': '/wiki/Summer_Sucks',
#   'title': 'Summer Sucks'},
#  22: {'date': '1998-08-19',
#   'id': 'ep22',
#   'wikiLink': '/wiki/Chef%27s_Chocolate_Salty_Balls',
#   'title': "Chef's Chocolate Salty Balls"},
#  23: {'date': '1998-08-26',
#   'id': 'ep23',
#   'wikiLink': '/wiki/Chickenpox_(South_Park)',
#   'title': 'Chickenpox (South Park)'},
#  24: {'date': '1998-09-02',
#   'id': 'ep24',
#   'wikiLink': '/wiki/Roger_Ebert_Should_Lay_Off_the_Fatty_Foods',
#   'title': 'Roger Ebert Should Lay Off the Fatty Foods'},
#  25: {'date': '1998-09-23',
#   'id': 'ep25',
#   'wikiLink': '/wiki/Clubhouses_(South_Park)',
#   'title': 'Clubhouses (South Park)'},
#  26: {'date': '1998-09-30',
#   'id': 'ep26',
#   'wikiLink': '/wiki/Cow_Days',
#   'title': 'Cow Days'},
#  27: {'date': '1998-10-07',
#   'id': 'ep27',
#   'wikiLink': '/wiki/Chef_Aid',
#   'title': 'Chef Aid'},
#  28: {'date': '1998-10-28',
#   'id': 'ep28',
#   'wikiLink': '/wiki/Spookyfish',
#   'title': 'Spookyfish'},
#  29: {'date': '1998-12-09',
#   'id': 'ep29',
#   'wikiLink': '/wiki/Merry_Christmas,_Charlie_Manson!',
#   'title': 'Merry Christmas, Charlie Manson!'},
#  30: {'date': '1998-12-16',
#   'id': 'ep30',
#   'wikiLink': '/wiki/Gnomes_(South_Park)',
#   'title': 'Gnomes (South Park)'},
#  31: {'date': '1999-01-20',
#   'id': 'ep31',
#   'wikiLink': '/wiki/Prehistoric_Ice_Man',
#   'title': 'Prehistoric Ice Man'},
#  32: {'date': '1999-04-07',
#   'id': 'ep32',
#   'wikiLink': '/wiki/Rainforest_Shmainforest',
#   'title': 'Rainforest Shmainforest'},
#  33: {'date': '1999-04-14',
#   'id': 'ep33',
#   'wikiLink': '/wiki/Spontaneous_Combustion_(South_Park)',
#   'title': 'Spontaneous Combustion (South Park)'},
#  34: {'date': '1999-04-21',
#   'id': 'ep34',
#   'wikiLink': '/wiki/Succubus_(South_Park)',
#   'title': 'Succubus (South Park)'},
#  35: {'date': '1999-06-16',
#   'id': 'ep35',
#   'wikiLink': '/wiki/Jakovasaurs',
#   'title': 'Jakovasaurs'},
#  36: {'date': '1999-06-23',
#   'id': 'ep36',
#   'wikiLink': '/wiki/Tweek_vs._Craig',
#   'title': 'Tweek vs. Craig'},
#  37: {'date': '1999-07-07',
#   'id': 'ep37',
#   'wikiLink': '/wiki/Sexual_Harassment_Panda',
#   'title': 'Sexual Harassment Panda'},
#  38: {'date': '1999-07-14',
#   'id': 'ep38',
#   'wikiLink': '/wiki/Cat_Orgy',
#   'title': 'Cat Orgy'},
#  39: {'date': '1999-07-21',
#   'id': 'ep39',
#   'wikiLink': '/wiki/Two_Guys_Naked_in_a_Hot_Tub',
#   'title': 'Two Guys Naked in a Hot Tub'},
#  40: {'date': '1999-07-28',
#   'id': 'ep40',
#   'wikiLink': '/wiki/Jewbilee',
#   'title': 'Jewbilee'},
#  41: {'date': '1999-10-27',
#   'id': 'ep41',
#   'wikiLink': '/wiki/Korn%27s_Groovy_Pirate_Ghost_Mystery',
#   'title': "Korn's Groovy Pirate Ghost Mystery"},
#  42: {'date': '1999-11-03',
#   'id': 'ep42',
#   'wikiLink': '/wiki/Chinpokomon',
#   'title': 'Chinpokomon'},
#  43: {'date': '1999-11-10',
#   'id': 'ep43',
#   'wikiLink': '/wiki/Hooked_on_Monkey_Fonics',
#   'title': 'Hooked on Monkey Fonics'},
#  44: {'date': '1999-11-17',
#   'id': 'ep44',
#   'wikiLink': '/wiki/Starvin%27_Marvin_in_Space',
#   'title': "Starvin' Marvin in Space"},
#  45: {'date': '1999-11-24',
#   'id': 'ep45',
#   'wikiLink': '/wiki/The_Red_Badge_of_Gayness',
#   'title': 'The Red Badge of Gayness'},
#  46: {'date': '1999-12-01',
#   'id': 'ep46',
#   'wikiLink': '/wiki/Mr._Hankey%27s_Christmas_Classics',
#   'title': "Mr. Hankey's Christmas Classics"},
#  47: {'date': '1999-12-29',
#   'id': 'ep47',
#   'wikiLink': '/wiki/Are_You_There_God%3F_It%27s_Me,_Jesus',
#   'title': "Are You There God? It's Me, Jesus"},
#  48: {'date': '2000-01-12',
#   'id': 'ep48',
#   'wikiLink': '/wiki/World_Wide_Recorder_Concert',
#   'title': 'World Wide Recorder Concert'},
#  49: {'date': '2000-04-05',
#   'id': 'ep49',
#   'wikiLink': '/wiki/The_Tooth_Fairy%27s_Tats_2000',
#   'title': "The Tooth Fairy's Tats 2000"},
#  50: {'date': '2000-04-12',
#   'id': 'ep50',
#   'wikiLink': '/wiki/Cartman%27s_Silly_Hate_Crime_2000',
#   'title': "Cartman's Silly Hate Crime 2000"},
#  51: {'date': '2000-04-19',
#   'id': 'ep51',
#   'wikiLink': '/wiki/Timmy_2000',
#   'title': 'Timmy 2000'},
#  52: {'date': '2000-04-26',
#   'id': 'ep52',
#   'wikiLink': '/wiki/Quintuplets_2000',
#   'title': 'Quintuplets 2000'},
#  53: {'date': '2000-06-21',
#   'id': 'ep53',
#   'wikiLink': '/wiki/Cartman_Joins_NAMBLA',
#   'title': 'Cartman Joins NAMBLA'},
#  54: {'date': '2000-06-28',
#   'id': 'ep54',
#   'wikiLink': '/wiki/Cherokee_Hair_Tampons',
#   'title': 'Cherokee Hair Tampons'},
#  55: {'date': '2000-07-05',
#   'id': 'ep55',
#   'wikiLink': '/wiki/Chef_Goes_Nanners',
#   'title': 'Chef Goes Nanners'},
#  56: {'date': '2000-07-12',
#   'id': 'ep56',
#   'wikiLink': '/wiki/Something_You_Can_Do_with_Your_Finger',
#   'title': 'Something You Can Do with Your Finger'},
#  57: {'date': '2000-07-19',
#   'id': 'ep57',
#   'wikiLink': '/wiki/Do_the_Handicapped_Go_to_Hell%3F',
#   'title': 'Do the Handicapped Go to Hell?'},
#  58: {'date': '2000-07-26',
#   'id': 'ep58',
#   'wikiLink': '/wiki/Probably_(South_Park)',
#   'title': 'Probably (South Park)'},
#  59: {'date': '2000-11-08',
#   'id': 'ep59',
#   'wikiLink': '/wiki/4th_Grade_(South_Park)',
#   'title': '4th Grade (South Park)'},
#  60: {'date': '2000-11-15',
#   'id': 'ep60',
#   'wikiLink': '/wiki/Trapper_Keeper_(South_Park)',
#   'title': 'Trapper Keeper (South Park)'},
#  61: {'date': '2000-11-22',
#   'id': 'ep61',
#   'wikiLink': '/wiki/Helen_Keller!_The_Musical',
#   'title': 'Helen Keller! The Musical'},
#  62: {'date': '2000-11-29',
#   'id': 'ep62',
#   'wikiLink': '/wiki/Pip_(South_Park)',
#   'title': 'Pip (South Park)'},
#  63: {'date': '2000-12-06',
#   'id': 'ep63',
#   'wikiLink': '/wiki/Fat_Camp_(South_Park)',
#   'title': 'Fat Camp (South Park)'},
#  64: {'date': '2000-12-13',
#   'id': 'ep64',
#   'wikiLink': '/wiki/The_Wacky_Molestation_Adventure',
#   'title': 'The Wacky Molestation Adventure'},
#  65: {'date': '2000-12-20',
#   'id': 'ep65',
#   'wikiLink': '/wiki/A_Very_Crappy_Christmas',
#   'title': 'A Very Crappy Christmas'},
#  66: {'date': '2001-06-20',
#   'id': 'ep66',
#   'wikiLink': '/wiki/It_Hits_the_Fan',
#   'title': 'It Hits the Fan'},
#  67: {'date': '2001-06-27',
#   'id': 'ep67',
#   'wikiLink': '/wiki/Cripple_Fight',
#   'title': 'Cripple Fight'},
#  68: {'date': '2001-07-04',
#   'id': 'ep68',
#   'wikiLink': '/wiki/Super_Best_Friends',
#   'title': 'Super Best Friends'},
#  69: {'date': '2001-07-11',
#   'id': 'ep69',
#   'wikiLink': '/wiki/Scott_Tenorman_Must_Die',
#   'title': 'Scott Tenorman Must Die'},
#  70: {'date': '2001-07-18',
#   'id': 'ep70',
#   'wikiLink': '/wiki/Terrance_and_Phillip:_Behind_the_Blow',
#   'title': 'Terrance and Phillip: Behind the Blow'},
#  71: {'date': '2001-07-25',
#   'id': 'ep71',
#   'wikiLink': '/wiki/Cartmanland',
#   'title': 'Cartmanland'},
#  72: {'date': '2001-08-01',
#   'id': 'ep72',
#   'wikiLink': '/wiki/Proper_Condom_Use',
#   'title': 'Proper Condom Use'},
#  73: {'date': '2001-08-08',
#   'id': 'ep73',
#   'wikiLink': '/wiki/Towelie',
#   'title': 'Towelie'},
#  74: {'date': '2001-11-07',
#   'id': 'ep74',
#   'wikiLink': '/wiki/Osama_bin_Laden_Has_Farty_Pants',
#   'title': 'Osama bin Laden Has Farty Pants'},
#  75: {'date': '2001-11-14',
#   'id': 'ep75',
#   'wikiLink': '/wiki/How_to_Eat_with_Your_Butt',
#   'title': 'How to Eat with Your Butt'},
#  76: {'date': '2001-11-21',
#   'id': 'ep76',
#   'wikiLink': '/wiki/The_Entity_(South_Park)',
#   'title': 'The Entity (South Park)'},
#  77: {'date': '2001-11-28',
#   'id': 'ep77',
#   'wikiLink': '/wiki/Here_Comes_the_Neighborhood',
#   'title': 'Here Comes the Neighborhood'},
#  78: {'date': '2001-12-05',
#   'id': 'ep78',
#   'wikiLink': '/wiki/Kenny_Dies',
#   'title': 'Kenny Dies'},
#  79: {'date': '2001-12-12',
#   'id': 'ep79',
#   'wikiLink': '/wiki/Butters%27_Very_Own_Episode',
#   'title': "Butters' Very Own Episode"},
#  80: {'date': '2002-03-06',
#   'id': 'ep80',
#   'wikiLink': '/wiki/Jared_Has_Aides',
#   'title': 'Jared Has Aides'},
#  81: {'date': '2002-03-13',
#   'id': 'ep81',
#   'wikiLink': '/wiki/Asspen',
#   'title': 'Asspen'},
#  82: {'date': '2002-03-20',
#   'id': 'ep82',
#   'wikiLink': '/wiki/Freak_Strike',
#   'title': 'Freak Strike'},
#  83: {'date': '2002-03-27',
#   'id': 'ep83',
#   'wikiLink': '/wiki/Fun_with_Veal',
#   'title': 'Fun with Veal'},
#  84: {'date': '2002-04-03',
#   'id': 'ep84',
#   'wikiLink': '/wiki/The_New_Terrance_and_Phillip_Movie_Trailer',
#   'title': 'The New Terrance and Phillip Movie Trailer'},
#  85: {'date': '2002-04-10',
#   'id': 'ep85',
#   'wikiLink': '/wiki/Professor_Chaos',
#   'title': 'Professor Chaos'},
#  86: {'date': '2002-06-26',
#   'id': 'ep86',
#   'wikiLink': '/wiki/Simpsons_Already_Did_It',
#   'title': 'Simpsons Already Did It'},
#  87: {'date': '2002-07-03',
#   'id': 'ep87',
#   'wikiLink': '/wiki/Red_Hot_Catholic_Love',
#   'title': 'Red Hot Catholic Love'},
#  88: {'date': '2002-07-10',
#   'id': 'ep88',
#   'wikiLink': '/wiki/Free_Hat',
#   'title': 'Free Hat'},
#  89: {'date': '2002-07-17',
#   'id': 'ep89',
#   'wikiLink': '/wiki/Bebe%27s_Boobs_Destroy_Society',
#   'title': "Bebe's Boobs Destroy Society"},
#  90: {'date': '2002-07-24',
#   'id': 'ep90',
#   'wikiLink': '/wiki/Child_Abduction_Is_Not_Funny',
#   'title': 'Child Abduction Is Not Funny'},
#  91: {'date': '2002-11-06',
#   'id': 'ep91',
#   'wikiLink': '/wiki/A_Ladder_to_Heaven',
#   'title': 'A Ladder to Heaven'},
#  92: {'date': '2002-11-13',
#   'id': 'ep92',
#   'wikiLink': '/wiki/The_Return_of_the_Fellowship_of_the_Ring_to_the_Two_Towers',
#   'title': 'The Return of the Fellowship of the Ring to the Two Towers'},
#  93: {'date': '2002-11-20',
#   'id': 'ep93',
#   'wikiLink': '/wiki/The_Death_Camp_of_Tolerance',
#   'title': 'The Death Camp of Tolerance'},
#  94: {'date': '2002-11-27',
#   'id': 'ep94',
#   'wikiLink': '/wiki/The_Biggest_Douche_in_the_Universe',
#   'title': 'The Biggest Douche in the Universe'},
#  95: {'date': '2002-12-04',
#   'id': 'ep95',
#   'wikiLink': '/wiki/My_Future_Self_%27n%27_Me',
#   'title': "My Future Self 'n' Me"},
#  96: {'date': '2002-12-11',
#   'id': 'ep96',
#   'wikiLink': '/wiki/Red_Sleigh_Down',
#   'title': 'Red Sleigh Down'},
#  97: {'date': '2003-03-19',
#   'id': 'ep97',
#   'wikiLink': '/wiki/Cancelled_(South_Park)',
#   'title': 'Cancelled (South Park)'},
#  98: {'date': '2003-03-26',
#   'id': 'ep98',
#   'wikiLink': '/wiki/Krazy_Kripples',
#   'title': 'Krazy Kripples'},
#  99: {'date': '2003-04-02',
#   'id': 'ep99',
#   'wikiLink': '/wiki/Toilet_Paper_(South_Park)',
#   'title': 'Toilet Paper (South Park)'},
#  100: {'date': '2003-04-09',
#   'id': 'ep100',
#   'wikiLink': '/wiki/I%27m_a_Little_Bit_Country',
#   'title': "I'm a Little Bit Country"},
#  101: {'date': '2003-04-16',
#   'id': 'ep101',
#   'wikiLink': '/wiki/Fat_Butt_and_Pancake_Head',
#   'title': 'Fat Butt and Pancake Head'},
#  102: {'date': '2003-04-23',
#   'id': 'ep102',
#   'wikiLink': '/wiki/Lil%27_Crime_Stoppers',
#   'title': "Lil' Crime Stoppers"},
#  103: {'date': '2003-04-30',
#   'id': 'ep103',
#   'wikiLink': '/wiki/Red_Man%27s_Greed',
#   'title': "Red Man's Greed"},
#  104: {'date': '2003-10-22',
#   'id': 'ep104',
#   'wikiLink': '/wiki/South_Park_Is_Gay',
#   'title': 'South Park Is Gay'},
#  105: {'date': '2003-10-29',
#   'id': 'ep105',
#   'wikiLink': '/wiki/Christian_Rock_Hard',
#   'title': 'Christian Rock Hard'},
#  106: {'date': '2003-11-05',
#   'id': 'ep106',
#   'wikiLink': '/wiki/Grey_Dawn_(South_Park)',
#   'title': 'Grey Dawn (South Park)'},
#  107: {'date': '2003-11-12',
#   'id': 'ep107',
#   'wikiLink': '/wiki/Casa_Bonita_(South_Park)',
#   'title': 'Casa Bonita (South Park)'},
#  108: {'date': '2003-11-19',
#   'id': 'ep108',
#   'wikiLink': '/wiki/All_About_Mormons',
#   'title': 'All About Mormons'},
#  109: {'date': '2003-12-03',
#   'id': 'ep109',
#   'wikiLink': '/wiki/Butt_Out',
#   'title': 'Butt Out'},
#  110: {'date': '2003-12-10',
#   'id': 'ep110',
#   'wikiLink': '/wiki/Raisins_(South_Park)',
#   'title': 'Raisins (South Park)'},
#  111: {'date': '2003-12-17',
#   'id': 'ep111',
#   'wikiLink': '/wiki/It%27s_Christmas_in_Canada',
#   'title': "It's Christmas in Canada"},
#  112: {'date': '2004-03-17',
#   'id': 'ep112',
#   'wikiLink': '/wiki/Good_Times_with_Weapons',
#   'title': 'Good Times with Weapons'},
#  113: {'date': '2004-03-24',
#   'id': 'ep113',
#   'wikiLink': '/wiki/Up_the_Down_Steroid',
#   'title': 'Up the Down Steroid'},
#  114: {'date': '2004-03-31',
#   'id': 'ep114',
#   'wikiLink': '/wiki/The_Passion_of_the_Jew',
#   'title': 'The Passion of the Jew'},
#  115: {'date': '2004-04-07',
#   'id': 'ep115',
#   'wikiLink': '/wiki/You_Got_F%27d_in_the_A',
#   'title': "You Got F'd in the A"},
#  116: {'date': '2004-04-14',
#   'id': 'ep116',
#   'wikiLink': '/wiki/Awesom-O',
#   'title': 'Awesom-O'},
#  117: {'date': '2004-04-21',
#   'id': 'ep117',
#   'wikiLink': '/wiki/The_Jeffersons_(South_Park)',
#   'title': 'The Jeffersons (South Park)'},
#  118: {'date': '2004-04-28',
#   'id': 'ep118',
#   'wikiLink': '/wiki/Goobacks',
#   'title': 'Goobacks'},
#  119: {'date': '2004-10-27',
#   'id': 'ep119',
#   'wikiLink': '/wiki/Douche_and_Turd',
#   'title': 'Douche and Turd'},
#  120: {'date': '2004-11-03',
#   'id': 'ep120',
#   'wikiLink': '/wiki/Something_Wall-Mart_This_Way_Comes',
#   'title': 'Something Wall-Mart This Way Comes'},
#  121: {'date': '2004-11-10',
#   'id': 'ep121',
#   'wikiLink': '/wiki/Pre-School_(South_Park)',
#   'title': 'Pre-School (South Park)'},
#  122: {'date': '2004-11-17',
#   'id': 'ep122',
#   'wikiLink': '/wiki/Quest_for_Ratings',
#   'title': 'Quest for Ratings'},
#  123: {'date': '2004-12-01',
#   'id': 'ep123',
#   'wikiLink': '/wiki/Stupid_Spoiled_Whore_Video_Playset',
#   'title': 'Stupid Spoiled Whore Video Playset'},
#  124: {'date': '2004-12-08',
#   'id': 'ep124',
#   'wikiLink': '/wiki/Cartman%27s_Incredible_Gift',
#   'title': "Cartman's Incredible Gift"},
#  125: {'date': '2004-12-15',
#   'id': 'ep125',
#   'wikiLink': '/wiki/Woodland_Critter_Christmas',
#   'title': 'Woodland Critter Christmas'},
#  126: {'date': '2005-03-09',
#   'id': 'ep126',
#   'wikiLink': '/wiki/Mr._Garrison%27s_Fancy_New_Vagina',
#   'title': "Mr. Garrison's Fancy New Vagina"},
#  127: {'date': '2005-03-16',
#   'id': 'ep127',
#   'wikiLink': '/wiki/Die_Hippie,_Die',
#   'title': 'Die Hippie, Die'},
#  128: {'date': '2005-03-23',
#   'id': 'ep128',
#   'wikiLink': '/wiki/Wing_(South_Park)',
#   'title': 'Wing (South Park)'},
#  129: {'date': '2005-03-30',
#   'id': 'ep129',
#   'wikiLink': '/wiki/Best_Friends_Forever_(South_Park)',
#   'title': 'Best Friends Forever (South Park)'},
#  130: {'date': '2005-04-06',
#   'id': 'ep130',
#   'wikiLink': '/wiki/The_Losing_Edge',
#   'title': 'The Losing Edge'},
#  131: {'date': '2005-04-13',
#   'id': 'ep131',
#   'wikiLink': '/wiki/The_Death_of_Eric_Cartman',
#   'title': 'The Death of Eric Cartman'},
#  132: {'date': '2005-04-20',
#   'id': 'ep132',
#   'wikiLink': '/wiki/Erection_Day',
#   'title': 'Erection Day'},
#  133: {'date': '2005-10-19',
#   'id': 'ep133',
#   'wikiLink': '/wiki/Two_Days_Before_the_Day_After_Tomorrow',
#   'title': 'Two Days Before the Day After Tomorrow'},
#  134: {'date': '2005-10-26',
#   'id': 'ep134',
#   'wikiLink': '/wiki/Marjorine',
#   'title': 'Marjorine'},
#  135: {'date': '2005-11-02',
#   'id': 'ep135',
#   'wikiLink': '/wiki/Follow_That_Egg!',
#   'title': 'Follow That Egg!'},
#  136: {'date': '2005-11-09',
#   'id': 'ep136',
#   'wikiLink': '/wiki/Ginger_Kids',
#   'title': 'Ginger Kids'},
#  137: {'date': '2005-11-16',
#   'id': 'ep137',
#   'wikiLink': '/wiki/Trapped_in_the_Closet_(South_Park)',
#   'title': 'Trapped in the Closet (South Park)'},
#  138: {'date': '2005-11-30',
#   'id': 'ep138',
#   'wikiLink': '/wiki/Free_Willzyx',
#   'title': 'Free Willzyx'},
#  139: {'date': '2005-12-07',
#   'id': 'ep139',
#   'wikiLink': '/wiki/Bloody_Mary_(South_Park)',
#   'title': 'Bloody Mary (South Park)'},
#  140: {'date': '2006-03-22',
#   'id': 'ep140',
#   'wikiLink': '/wiki/The_Return_of_Chef',
#   'title': 'The Return of Chef'},
#  141: {'date': '2006-03-29',
#   'id': 'ep141',
#   'wikiLink': '/wiki/Smug_Alert!',
#   'title': 'Smug Alert!'},
#  142: {'date': '2006-04-05',
#   'id': 'ep142',
#   'wikiLink': '/wiki/Cartoon_Wars_Part_I',
#   'title': 'Cartoon Wars Part I'},
#  143: {'date': '2006-04-12',
#   'id': 'ep143',
#   'wikiLink': '/wiki/Cartoon_Wars_Part_II',
#   'title': 'Cartoon Wars Part II'},
#  144: {'date': '2006-04-19',
#   'id': 'ep144',
#   'wikiLink': '/wiki/A_Million_Little_Fibers',
#   'title': 'A Million Little Fibers'},
#  145: {'date': '2006-04-26',
#   'id': 'ep145',
#   'wikiLink': '/wiki/ManBearPig',
#   'title': 'ManBearPig'},
#  146: {'date': '2006-05-03',
#   'id': 'ep146',
#   'wikiLink': '/wiki/Tsst',
#   'title': 'Tsst'},
#  147: {'date': '2006-10-04',
#   'id': 'ep147',
#   'wikiLink': '/wiki/Make_Love,_Not_Warcraft',
#   'title': 'Make Love, Not Warcraft'},
#  148: {'date': '2006-10-11',
#   'id': 'ep148',
#   'wikiLink': '/wiki/Mystery_of_the_Urinal_Deuce',
#   'title': 'Mystery of the Urinal Deuce'},
#  149: {'date': '2006-10-18',
#   'id': 'ep149',
#   'wikiLink': '/wiki/Miss_Teacher_Bangs_a_Boy',
#   'title': 'Miss Teacher Bangs a Boy'},
#  150: {'date': '2006-10-25',
#   'id': 'ep150',
#   'wikiLink': '/wiki/Hell_on_Earth_2006',
#   'title': 'Hell on Earth 2006'},
#  151: {'date': '2006-11-01',
#   'id': 'ep151',
#   'wikiLink': '/wiki/Go_God_Go',
#   'title': 'Go God Go'},
#  152: {'date': '2006-11-08',
#   'id': 'ep152',
#   'wikiLink': '/wiki/Go_God_Go_XII',
#   'title': 'Go God Go XII'},
#  153: {'date': '2006-11-15',
#   'id': 'ep153',
#   'wikiLink': '/wiki/Stanley%27s_Cup',
#   'title': "Stanley's Cup"},
#  154: {'date': '2007-03-07',
#   'id': 'ep154',
#   'wikiLink': '/wiki/With_Apologies_to_Jesse_Jackson',
#   'title': 'With Apologies to Jesse Jackson'},
#  155: {'date': '2007-03-14',
#   'id': 'ep155',
#   'wikiLink': '/wiki/Cartman_Sucks',
#   'title': 'Cartman Sucks'},
#  156: {'date': '2007-03-21',
#   'id': 'ep156',
#   'wikiLink': '/wiki/Lice_Capades',
#   'title': 'Lice Capades'},
#  157: {'date': '2007-03-28',
#   'id': 'ep157',
#   'wikiLink': '/wiki/The_Snuke',
#   'title': 'The Snuke'},
#  158: {'date': '2007-04-04',
#   'id': 'ep158',
#   'wikiLink': '/wiki/Fantastic_Easter_Special',
#   'title': 'Fantastic Easter Special'},
#  159: {'date': '2007-04-11',
#   'id': 'ep159',
#   'wikiLink': '/wiki/D-Yikes!',
#   'title': 'D-Yikes!'},
#  160: {'date': '2007-04-18',
#   'id': 'ep160',
#   'wikiLink': '/wiki/Night_of_the_Living_Homeless',
#   'title': 'Night of the Living Homeless'},
#  161: {'date': '2007-10-03',
#   'id': 'ep161',
#   'wikiLink': '/wiki/Le_Petit_Tourette',
#   'title': 'Le Petit Tourette'},
#  162: {'date': '2007-10-10',
#   'id': 'ep162',
#   'wikiLink': '/wiki/More_Crap',
#   'title': 'More Crap'},
#  163: {'date': '2007-10-17',
#   'id': 'ep163',
#   'wikiLink': '/wiki/Imaginationland_Episode_I',
#   'title': 'Imaginationland Episode I'},
#  164: {'date': '2007-10-24',
#   'id': 'ep164',
#   'wikiLink': '/wiki/Imaginationland_Episode_II',
#   'title': 'Imaginationland Episode II'},
#  165: {'date': '2007-10-31',
#   'id': 'ep165',
#   'wikiLink': '/wiki/Imaginationland_Episode_III',
#   'title': 'Imaginationland Episode III'},
#  166: {'date': '2007-11-07',
#   'id': 'ep166',
#   'wikiLink': '/wiki/Guitar_Queer-O',
#   'title': 'Guitar Queer-O'},
#  167: {'date': '2007-11-14',
#   'id': 'ep167',
#   'wikiLink': '/wiki/The_List_(South_Park)',
#   'title': 'The List (South Park)'},
#  168: {'date': '2008-03-12',
#   'id': 'ep168',
#   'wikiLink': '/wiki/Tonsil_Trouble',
#   'title': 'Tonsil Trouble'},
#  169: {'date': '2008-03-19',
#   'id': 'ep169',
#   'wikiLink': '/wiki/Britney%27s_New_Look',
#   'title': "Britney's New Look"},
#  170: {'date': '2008-03-26',
#   'id': 'ep170',
#   'wikiLink': '/wiki/Major_Boobage',
#   'title': 'Major Boobage'},
#  171: {'date': '2008-04-02',
#   'id': 'ep171',
#   'wikiLink': '/wiki/Canada_on_Strike',
#   'title': 'Canada on Strike'},
#  172: {'date': '2008-04-09',
#   'id': 'ep172',
#   'wikiLink': '/wiki/Eek,_a_Penis!',
#   'title': 'Eek, a Penis!'},
#  173: {'date': '2008-04-16',
#   'id': 'ep173',
#   'wikiLink': '/wiki/Over_Logging',
#   'title': 'Over Logging'},
#  174: {'date': '2008-04-23',
#   'id': 'ep174',
#   'wikiLink': '/wiki/Super_Fun_Time',
#   'title': 'Super Fun Time'},
#  175: {'date': '2008-10-08',
#   'id': 'ep175',
#   'wikiLink': '/wiki/The_China_Probrem',
#   'title': 'The China Probrem'},
#  176: {'date': '2008-10-15',
#   'id': 'ep176',
#   'wikiLink': '/wiki/Breast_Cancer_Show_Ever',
#   'title': 'Breast Cancer Show Ever'},
#  177: {'date': '2008-10-22',
#   'id': 'ep177',
#   'wikiLink': '/wiki/Pandemic_(South_Park)',
#   'title': 'Pandemic (South Park)'},
#  178: {'date': '2008-10-29',
#   'id': 'ep178',
#   'wikiLink': '/wiki/Pandemic_2:_The_Startling',
#   'title': 'Pandemic 2: The Startling'},
#  179: {'date': '2008-11-05',
#   'id': 'ep179',
#   'wikiLink': '/wiki/About_Last_Night..._(South_Park)',
#   'title': 'About Last Night... (South Park)'},
#  180: {'date': '2008-11-12',
#   'id': 'ep180',
#   'wikiLink': '/wiki/Elementary_School_Musical_(South_Park)',
#   'title': 'Elementary School Musical (South Park)'},
#  181: {'date': '2008-11-19',
#   'id': 'ep181',
#   'wikiLink': '/wiki/The_Ungroundable',
#   'title': 'The Ungroundable'},
#  182: {'date': '2009-03-11',
#   'id': 'ep182',
#   'wikiLink': '/wiki/The_Ring_(South_Park)',
#   'title': 'The Ring (South Park)'},
#  183: {'date': '2009-03-18',
#   'id': 'ep183',
#   'wikiLink': '/wiki/The_Coon',
#   'title': 'The Coon'},
#  184: {'date': '2009-03-25',
#   'id': 'ep184',
#   'wikiLink': '/wiki/Margaritaville_(South_Park)',
#   'title': 'Margaritaville (South Park)'},
#  185: {'date': '2009-04-01',
#   'id': 'ep185',
#   'wikiLink': '/wiki/Eat,_Pray,_Queef',
#   'title': 'Eat, Pray, Queef'},
#  186: {'date': '2009-04-08',
#   'id': 'ep186',
#   'wikiLink': '/wiki/Fishsticks_(South_Park)',
#   'title': 'Fishsticks (South Park)'},
#  187: {'date': '2009-04-15',
#   'id': 'ep187',
#   'wikiLink': '/wiki/Pinewood_Derby_(South_Park)',
#   'title': 'Pinewood Derby (South Park)'},
#  188: {'date': '2009-04-22',
#   'id': 'ep188',
#   'wikiLink': '/wiki/Fatbeard',
#   'title': 'Fatbeard'},
#  189: {'date': '2009-10-07',
#   'id': 'ep189',
#   'wikiLink': '/wiki/Dead_Celebrities',
#   'title': 'Dead Celebrities'},
#  190: {'date': '2009-10-14',
#   'id': 'ep190',
#   'wikiLink': '/wiki/Butters%27_Bottom_Bitch',
#   'title': "Butters' Bottom Bitch"},
#  191: {'date': '2009-10-21',
#   'id': 'ep191',
#   'wikiLink': '/wiki/W.T.F._(South_Park)',
#   'title': 'W.T.F. (South Park)'},
#  192: {'date': '2009-10-28',
#   'id': 'ep192',
#   'wikiLink': '/wiki/Whale_Whores',
#   'title': 'Whale Whores'},
#  193: {'date': '2009-11-04',
#   'id': 'ep193',
#   'wikiLink': '/wiki/The_F_Word_(South_Park)',
#   'title': 'The F Word (South Park)'},
#  194: {'date': '2009-11-11',
#   'id': 'ep194',
#   'wikiLink': '/wiki/Dances_with_Smurfs',
#   'title': 'Dances with Smurfs'},
#  195: {'date': '2009-11-18',
#   'id': 'ep195',
#   'wikiLink': '/wiki/Pee_(South_Park)',
#   'title': 'Pee (South Park)'},
#  196: {'date': '2010-03-17',
#   'id': 'ep196',
#   'wikiLink': '/wiki/Sexual_Healing_(South_Park)',
#   'title': 'Sexual Healing (South Park)'},
#  197: {'date': '2010-03-24',
#   'id': 'ep197',
#   'wikiLink': '/wiki/The_Tale_of_Scrotie_McBoogerballs',
#   'title': 'The Tale of Scrotie McBoogerballs'},
#  198: {'date': '2010-03-31',
#   'id': 'ep198',
#   'wikiLink': '/wiki/Medicinal_Fried_Chicken',
#   'title': 'Medicinal Fried Chicken'},
#  199: {'date': '2010-04-07',
#   'id': 'ep199',
#   'wikiLink': '/wiki/You_Have_0_Friends',
#   'title': 'You Have 0 Friends'},
#  200: {'date': '2010-04-14',
#   'id': 'ep200',
#   'wikiLink': '/wiki/200_(South_Park)',
#   'title': '200 (South Park)'},
#  201: {'date': '2010-04-21',
#   'id': 'ep201',
#   'wikiLink': '/wiki/201_(South_Park)',
#   'title': '201 (South Park)'},
#  202: {'date': '2010-04-28',
#   'id': 'ep202',
#   'wikiLink': '/wiki/Crippled_Summer',
#   'title': 'Crippled Summer'},
#  203: {'date': '2010-10-06',
#   'id': 'ep203',
#   'wikiLink': '/wiki/Poor_and_Stupid',
#   'title': 'Poor and Stupid'},
#  204: {'date': '2010-10-13',
#   'id': 'ep204',
#   'wikiLink': '/wiki/It%27s_a_Jersey_Thing',
#   'title': "It's a Jersey Thing"},
#  205: {'date': '2010-10-20',
#   'id': 'ep205',
#   'wikiLink': '/wiki/Insheeption',
#   'title': 'Insheeption'},
#  206: {'date': '2010-10-27',
#   'id': 'ep206',
#   'wikiLink': '/wiki/Coon_2:_Hindsight',
#   'title': 'Coon 2: Hindsight'},
#  207: {'date': '2010-11-03',
#   'id': 'ep207',
#   'wikiLink': '/wiki/Mysterion_Rises',
#   'title': 'Mysterion Rises'},
#  208: {'date': '2010-11-10',
#   'id': 'ep208',
#   'wikiLink': '/wiki/Coon_vs._Coon_and_Friends',
#   'title': 'Coon vs. Coon and Friends'},
#  209: {'date': '2010-11-17',
#   'id': 'ep209',
#   'wikiLink': '/wiki/Cr%C3%A8me_Fra%C3%AEche_(South_Park)',
#   'title': 'Crème Fraîche (South Park)'},
#  210: {'date': '2011-04-27',
#   'id': 'ep210',
#   'wikiLink': '/wiki/HumancentiPad',
#   'title': 'HumancentiPad'},
#  211: {'date': '2011-05-04',
#   'id': 'ep211',
#   'wikiLink': '/wiki/Funnybot',
#   'title': 'Funnybot'},
#  212: {'date': '2011-05-11',
#   'id': 'ep212',
#   'wikiLink': '/wiki/Royal_Pudding',
#   'title': 'Royal Pudding'},
#  213: {'date': '2011-05-18',
#   'id': 'ep213',
#   'wikiLink': '/wiki/T.M.I._(South_Park)',
#   'title': 'T.M.I. (South Park)'},
#  214: {'date': '2011-05-25',
#   'id': 'ep214',
#   'wikiLink': '/wiki/Crack_Baby_Athletic_Association',
#   'title': 'Crack Baby Athletic Association'},
#  215: {'date': '2011-06-01',
#   'id': 'ep215',
#   'wikiLink': '/wiki/City_Sushi',
#   'title': 'City Sushi'},
#  216: {'date': '2011-06-08',
#   'id': 'ep216',
#   'wikiLink': '/wiki/You%27re_Getting_Old',
#   'title': "You're Getting Old"},
#  217: {'date': '2011-10-05',
#   'id': 'ep217',
#   'wikiLink': '/wiki/Ass_Burgers',
#   'title': 'Ass Burgers'},
#  218: {'date': '2011-10-12',
#   'id': 'ep218',
#   'wikiLink': '/wiki/The_Last_of_the_Meheecans',
#   'title': 'The Last of the Meheecans'},
#  219: {'date': '2011-10-19',
#   'id': 'ep219',
#   'wikiLink': '/wiki/Bass_to_Mouth',
#   'title': 'Bass to Mouth'},
#  220: {'date': '2011-10-26',
#   'id': 'ep220',
#   'wikiLink': '/wiki/Broadway_Bro_Down',
#   'title': 'Broadway Bro Down'},
#  221: {'date': '2011-11-02',
#   'id': 'ep221',
#   'wikiLink': '/wiki/1%25_(South_Park)',
#   'title': '1% (South Park)'},
#  222: {'date': '2011-11-09',
#   'id': 'ep222',
#   'wikiLink': '/wiki/A_History_Channel_Thanksgiving',
#   'title': 'A History Channel Thanksgiving'},
#  223: {'date': '2011-11-16',
#   'id': 'ep223',
#   'wikiLink': '/wiki/The_Poor_Kid',
#   'title': 'The Poor Kid'},
#  224: {'date': '2012-03-14',
#   'id': 'ep224',
#   'wikiLink': '/wiki/Reverse_Cowgirl_(South_Park)',
#   'title': 'Reverse Cowgirl (South Park)'},
#  225: {'date': '2012-03-21',
#   'id': 'ep225',
#   'wikiLink': '/wiki/Cash_for_Gold_(South_Park)',
#   'title': 'Cash for Gold (South Park)'},
#  226: {'date': '2012-03-28',
#   'id': 'ep226',
#   'wikiLink': '/wiki/Faith_Hilling',
#   'title': 'Faith Hilling'},
#  227: {'date': '2012-04-04',
#   'id': 'ep227',
#   'wikiLink': '/wiki/Jewpacabra',
#   'title': 'Jewpacabra'},
#  228: {'date': '2012-04-11',
#   'id': 'ep228',
#   'wikiLink': '/wiki/Butterballs_(South_Park)',
#   'title': 'Butterballs (South Park)'},
#  229: {'date': '2012-04-18',
#   'id': 'ep229',
#   'wikiLink': '/wiki/I_Should_Have_Never_Gone_Ziplining',
#   'title': 'I Should Have Never Gone Ziplining'},
#  230: {'date': '2012-04-25',
#   'id': 'ep230',
#   'wikiLink': '/wiki/Cartman_Finds_Love',
#   'title': 'Cartman Finds Love'},
#  231: {'date': '2012-09-26',
#   'id': 'ep231',
#   'wikiLink': '/wiki/Sarcastaball',
#   'title': 'Sarcastaball'},
#  232: {'date': '2012-10-03',
#   'id': 'ep232',
#   'wikiLink': '/wiki/Raising_the_Bar_(South_Park)',
#   'title': 'Raising the Bar (South Park)'},
#  233: {'date': '2012-10-10',
#   'id': 'ep233',
#   'wikiLink': '/wiki/Insecurity_(South_Park)',
#   'title': 'Insecurity (South Park)'},
#  234: {'date': '2012-10-17',
#   'id': 'ep234',
#   'wikiLink': '/wiki/Going_Native',
#   'title': 'Going Native'},
#  235: {'date': '2012-10-24',
#   'id': 'ep235',
#   'wikiLink': '/wiki/A_Nightmare_on_FaceTime',
#   'title': 'A Nightmare on FaceTime'},
#  236: {'date': '2012-10-31',
#   'id': 'ep236',
#   'wikiLink': '/wiki/A_Scause_for_Applause',
#   'title': 'A Scause for Applause'},
#  237: {'date': '2012-11-07',
#   'id': 'ep237',
#   'wikiLink': '/wiki/Obama_Wins!',
#   'title': 'Obama Wins!'},
#  238: {'date': '2013-09-25',
#   'id': 'ep238',
#   'wikiLink': '/wiki/Let_Go,_Let_Gov',
#   'title': 'Let Go, Let Gov'},
#  239: {'date': '2013-10-02',
#   'id': 'ep239',
#   'wikiLink': '/wiki/Informative_Murder_Porn',
#   'title': 'Informative Murder Porn'},
#  240: {'date': '2013-10-09',
#   'id': 'ep240',
#   'wikiLink': '/wiki/World_War_Zimmerman',
#   'title': 'World War Zimmerman'},
#  241: {'date': '2013-10-23',
#   'id': 'ep241',
#   'wikiLink': '/wiki/Goth_Kids_3:_Dawn_of_the_Posers',
#   'title': 'Goth Kids 3: Dawn of the Posers'},
#  242: {'date': '2013-10-30',
#   'id': 'ep242',
#   'wikiLink': '/wiki/Taming_Strange',
#   'title': 'Taming Strange'},
#  243: {'date': '2013-11-06',
#   'id': 'ep243',
#   'wikiLink': '/wiki/Ginger_Cow',
#   'title': 'Ginger Cow'},
#  244: {'date': '2013-11-13',
#   'id': 'ep244',
#   'wikiLink': '/wiki/Black_Friday_(South_Park)',
#   'title': 'Black Friday (South Park)'},
#  245: {'date': '2013-11-20',
#   'id': 'ep245',
#   'wikiLink': '/wiki/A_Song_of_Ass_and_Fire',
#   'title': 'A Song of Ass and Fire'},
#  246: {'date': '2013-12-04',
#   'id': 'ep246',
#   'wikiLink': '/wiki/Titties_and_Dragons',
#   'title': 'Titties and Dragons'},
#  247: {'date': '2013-12-11',
#   'id': 'ep247',
#   'wikiLink': '/wiki/The_Hobbit_(South_Park)',
#   'title': 'The Hobbit (South Park)'},
#  248: {'date': '2014-09-24',
#   'id': 'ep248',
#   'wikiLink': '/wiki/Go_Fund_Yourself',
#   'title': 'Go Fund Yourself'},
#  249: {'date': '2014-10-01',
#   'id': 'ep249',
#   'wikiLink': '/wiki/Gluten_Free_Ebola',
#   'title': 'Gluten Free Ebola'},
#  250: {'date': '2014-10-08',
#   'id': 'ep250',
#   'wikiLink': '/wiki/The_Cissy',
#   'title': 'The Cissy'},
#  251: {'date': '2014-10-15',
#   'id': 'ep251',
#   'wikiLink': '/wiki/Handicar',
#   'title': 'Handicar'},
#  252: {'date': '2014-10-29',
#   'id': 'ep252',
#   'wikiLink': '/wiki/The_Magic_Bush',
#   'title': 'The Magic Bush'},
#  253: {'date': '2014-11-05',
#   'id': 'ep253',
#   'wikiLink': '/wiki/Freemium_Isn%27t_Free',
#   'title': "Freemium Isn't Free"},
#  254: {'date': '2014-11-12',
#   'id': 'ep254',
#   'wikiLink': '/wiki/Grounded_Vindaloop',
#   'title': 'Grounded Vindaloop'},
#  255: {'date': '2014-11-19',
#   'id': 'ep255',
#   'wikiLink': '/wiki/Cock_Magic',
#   'title': 'Cock Magic'},
#  256: {'date': '2014-12-03',
#   'id': 'ep256',
#   'wikiLink': '/wiki/Rehash_(South_Park)',
#   'title': 'Rehash (South Park)'},
#  257: {'date': '2014-12-10',
#   'id': 'ep257',
#   'wikiLink': '/wiki/HappyHolograms',
#   'title': 'HappyHolograms'},
#  258: {'date': '2015-09-16',
#   'id': 'ep258',
#   'wikiLink': '/wiki/Stunning_and_Brave',
#   'title': 'Stunning and Brave'},
#  259: {'date': '2015-09-23',
#   'id': 'ep259',
#   'wikiLink': '/wiki/Where_My_Country_Gone%3F',
#   'title': 'Where My Country Gone?'},
#  260: {'date': '2015-09-30',
#   'id': 'ep260',
#   'wikiLink': '/wiki/The_City_Part_of_Town',
#   'title': 'The City Part of Town'},
#  261: {'date': '2015-10-14',
#   'id': 'ep261',
#   'wikiLink': '/wiki/You%27re_Not_Yelping',
#   'title': "You're Not Yelping"},
#  262: {'date': '2015-10-21',
#   'id': 'ep262',
#   'wikiLink': '/wiki/Safe_Space_(South_Park)',
#   'title': 'Safe Space (South Park)'},
#  263: {'date': '2015-10-28',
#   'id': 'ep263',
#   'wikiLink': '/wiki/Tweek_x_Craig',
#   'title': 'Tweek x Craig'},
#  264: {'date': '2015-11-11',
#   'id': 'ep264',
#   'wikiLink': '/wiki/Naughty_Ninjas',
#   'title': 'Naughty Ninjas'},
#  265: {'date': '2015-11-18',
#   'id': 'ep265',
#   'wikiLink': '/wiki/Sponsored_Content_(South_Park)',
#   'title': 'Sponsored Content (South Park)'},
#  266: {'date': '2015-12-02',
#   'id': 'ep266',
#   'wikiLink': '/wiki/Truth_and_Advertising',
#   'title': 'Truth and Advertising'},
#  267: {'date': '2015-12-09',
#   'id': 'ep267',
#   'wikiLink': '/wiki/PC_Principal_Final_Justice',
#   'title': 'PC Principal Final Justice'},
#  268: {'date': '2016-09-14',
#   'id': 'ep268',
#   'wikiLink': '/wiki/Member_Berries',
#   'title': 'Member Berries'},
#  269: {'date': '2016-09-21',
#   'id': 'ep269',
#   'wikiLink': '/wiki/Skank_Hunt',
#   'title': 'Skank Hunt'},
#  270: {'date': '2016-09-28',
#   'id': 'ep270',
#   'wikiLink': '/wiki/The_Damned_(South_Park)',
#   'title': 'The Damned (South Park)'},
#  271: {'date': '2016-10-12',
#   'id': 'ep271',
#   'wikiLink': '/wiki/Wieners_Out',
#   'title': 'Wieners Out'},
#  272: {'date': '2016-10-19',
#   'id': 'ep272',
#   'wikiLink': '/wiki/Douche_and_a_Danish',
#   'title': 'Douche and a Danish'},
#  273: {'date': '2016-10-26',
#   'id': 'ep273',
#   'wikiLink': '/wiki/Fort_Collins_(South_Park)',
#   'title': 'Fort Collins (South Park)'},
#  274: {'date': '2016-11-09',
#   'id': 'ep274',
#   'wikiLink': '/wiki/Oh,_Jeez',
#   'title': 'Oh, Jeez'},
#  275: {'date': '2016-11-16',
#   'id': 'ep275',
#   'wikiLink': '/wiki/Members_Only_(South_Park)',
#   'title': 'Members Only (South Park)'},
#  276: {'date': '2016-11-30',
#   'id': 'ep276',
#   'wikiLink': '/wiki/Not_Funny',
#   'title': 'Not Funny'},
#  277: {'date': '2016-12-07',
#   'id': 'ep277',
#   'wikiLink': '/wiki/The_End_of_Serialization_as_We_Know_It',
#   'title': 'The End of Serialization as We Know It'},
#  278: {'date': '2017-09-13',
#   'id': 'ep278',
#   'wikiLink': '/wiki/White_People_Renovating_Houses',
#   'title': 'White People Renovating Houses'},
#  279: {'date': '2017-09-20',
#   'id': 'ep279',
#   'wikiLink': '/wiki/Put_It_Down_(South_Park)',
#   'title': 'Put It Down (South Park)'},
#  280: {'date': '2017-09-27',
#   'id': 'ep280',
#   'wikiLink': '/wiki/Holiday_Special_(South_Park)',
#   'title': 'Holiday Special (South Park)'},
#  281: {'date': '2017-10-11',
#   'id': 'ep281',
#   'wikiLink': '/wiki/Franchise_Prequel',
#   'title': 'Franchise Prequel'},
#  282: {'date': '2017-10-18',
#   'id': 'ep282',
#   'wikiLink': '/wiki/Hummels_%26_Heroin',
#   'title': 'Hummels & Heroin'},
#  283: {'date': '2017-10-25',
#   'id': 'ep283',
#   'wikiLink': '/wiki/Sons_a_Witches',
#   'title': 'Sons a Witches'},
#  284: {'date': '2017-11-08',
#   'id': 'ep284',
#   'wikiLink': '/wiki/Doubling_Down_(South_Park)',
#   'title': 'Doubling Down (South Park)'},
#  285: {'date': '2017-11-15',
#   'id': 'ep285',
#   'wikiLink': '/wiki/Moss_Piglets_(South_Park)',
#   'title': 'Moss Piglets (South Park)'},
#  286: {'date': '2017-11-29',
#   'id': 'ep286',
#   'wikiLink': '/wiki/Super_Hard_PCness',
#   'title': 'Super Hard PCness'},
#  287: {'date': '2017-12-06',
#   'id': 'ep287',
#   'wikiLink': '/wiki/Splatty_Tomato',
#   'title': 'Splatty Tomato'},
#  288: {'date': '2018-09-26',
#   'id': 'ep288',
#   'wikiLink': '/wiki/Dead_Kids_(South_Park)',
#   'title': 'Dead Kids (South Park)'},
#  289: {'date': '2018-10-03',
#   'id': 'ep289',
#   'wikiLink': '/wiki/A_Boy_and_a_Priest',
#   'title': 'A Boy and a Priest'},
#  290: {'date': '2018-10-10',
#   'id': 'ep290',
#   'wikiLink': '/wiki/The_Problem_with_a_Poo',
#   'title': 'The Problem with a Poo'},
#  291: {'date': '2018-10-17',
#   'id': 'ep291',
#   'wikiLink': '/wiki/Tegridy_Farms',
#   'title': 'Tegridy Farms'},
#  292: {'date': '2018-10-31',
#   'id': 'ep292',
#   'wikiLink': '/wiki/The_Scoots',
#   'title': 'The Scoots'},
#  293: {'date': '2018-11-07',
#   'id': 'ep293',
#   'wikiLink': '/wiki/Time_to_Get_Cereal',
#   'title': 'Time to Get Cereal'},
#  294: {'date': '2018-11-14',
#   'id': 'ep294',
#   'wikiLink': '/wiki/Nobody_Got_Cereal%3F',
#   'title': 'Nobody Got Cereal?'},
#  295: {'date': '2018-11-28',
#   'id': 'ep295',
#   'wikiLink': '/wiki/Buddha_Box',
#   'title': 'Buddha Box'},
#  296: {'date': '2018-12-05',
#   'id': 'ep296',
#   'wikiLink': '/wiki/Unfulfilled',
#   'title': 'Unfulfilled'},
#  297: {'date': '2018-12-12',
#   'id': 'ep297',
#   'wikiLink': '/wiki/Bike_Parade',
#   'title': 'Bike Parade'},
#  298: {'date': '2019-09-25',
#   'id': 'ep298',
#   'wikiLink': '/wiki/Mexican_Joker',
#   'title': 'Mexican Joker'},
#  299: {'date': '2019-10-02',
#   'id': 'ep299',
#   'wikiLink': '/wiki/Band_in_China',
#   'title': 'Band in China'},
#  300: {'date': '2019-10-09',
#   'id': 'ep300',
#   'wikiLink': '/wiki/Shots!!!',
#   'title': 'Shots!!!'},
#  301: {'date': '2019-10-16',
#   'id': 'ep301',
#   'wikiLink': '/wiki/Let_Them_Eat_Goo',
#   'title': 'Let Them Eat Goo'},
#  302: {'date': '2019-10-30',
#   'id': 'ep302',
#   'wikiLink': '/wiki/Tegridy_Farms_Halloween_Special',
#   'title': 'Tegridy Farms Halloween Special'},
#  303: {'date': '2019-11-06',
#   'id': 'ep303',
#   'wikiLink': '/wiki/Season_Finale_(South_Park)',
#   'title': 'Season Finale (South Park)'},
#  304: {'date': '2019-11-13',
#   'id': 'ep304',
#   'wikiLink': '/wiki/Board_Girls',
#   'title': 'Board Girls'},
#  305: {'date': '2019-11-27',
#   'id': 'ep305',
#   'wikiLink': '/wiki/Turd_Burglars',
#   'title': 'Turd Burglars'},
#  306: {'date': '2019-12-04',
#   'id': 'ep306',
#   'wikiLink': '/wiki/Basic_Cable_(South_Park)',
#   'title': 'Basic Cable (South Park)'},
#  307: {'date': '2019-12-11',
#   'id': 'ep307',
#   'wikiLink': '/wiki/Christmas_Snow_(South_Park)',
#   'title': 'Christmas Snow (South Park)'},
#  308: {'date': '2020-09-30',
#   'id': 'ep308',
#   'wikiLink': '/wiki/The_Pandemic_Special',
#   'title': 'The Pandemic Special'},
#  309: {'date': '2021-03-10',
#   'id': 'ep309',
#   'wikiLink': '/wiki/South_ParQ_Vaccination_Special',
#   'title': 'South ParQ Vaccination Special'},
#  310: {'date': '2021-11-25',
#   'id': 'ep310',
#   'wikiLink': '/wiki/South_Park:_Post_Covid',
#   'title': 'South Park: Post Covid'},
#  311: {'date': '2021-12-16',
#   'id': 'ep311',
#   'wikiLink': '/wiki/South_Park:_Post_Covid:_The_Return_of_Covid',
#   'title': 'South Park: Post Covid: The Return of Covid'},
#  312: {'date': '2022-02-02',
#   'id': 'ep312',
#   'wikiLink': '/wiki/Pajama_Day_(South_Park)',
#   'title': 'Pajama Day (South Park)'},
#  313: {'date': '2022-02-09',
#   'id': 'ep313',
#   'wikiLink': '/wiki/The_Big_Fix_(South_Park)',
#   'title': 'The Big Fix (South Park)'},
#  314: {'date': '2022-02-16',
#   'id': 'ep314',
#   'wikiLink': '/wiki/City_People',
#   'title': 'City People'},
#  315: {'date': '2022-03-02',
#   'id': 'ep315',
#   'wikiLink': '/wiki/Back_to_the_Cold_War',
#   'title': 'Back to the Cold War'},
#  316: {'date': '2022-03-09',
#   'id': 'ep316',
#   'wikiLink': '/wiki/Help,_My_Teenager_Hates_Me!',
#   'title': 'Help, My Teenager Hates Me!'},
#  317: {'date': '2022-03-16',
#   'id': 'ep317',
#   'wikiLink': '/wiki/Credigree_Weed_St._Patrick%27s_Day_Special',
#   'title': "Credigree Weed St. Patrick's Day Special"},
#  318: {'date': '2022-06-01',
#   'id': 'ep318',
#   'wikiLink': '/wiki/South_Park_The_Streaming_Wars',
#   'title': 'South Park The Streaming Wars'},
#  319: {'date': '2022-07-13',
#   'id': 'ep319',
#   'wikiLink': '/wiki/South_Park_The_Streaming_Wars_Part_2',
#   'title': 'South Park The Streaming Wars Part 2'}}

# %%
def urllist(bs):
    hrefs = []
    for link in bs.find_all("a", href = True, title = True):
        linkref = link.get("href","")
        if linkref.split("/")[1] == "wiki":
            hrefs.append(linkref)
    return list(set(hrefs))

# %%
for key in epi.keys():
    epiurl = 'https://en.wikipedia.org'+epi[key]["wikiLink"]
    epipage = requests.get(epiurl)
    episoup = BeautifulSoup(epipage.content)
    epi[key]["reflinks"] = urllist(episoup)
    time.sleep(0.1)
df = pd.DataFrame.from_dict(epi, orient = "index")
df
# Out:
#            date     id                                          wikiLink  \
# 1    1997-08-13    ep1                  /wiki/Cartman_Gets_an_Anal_Probe
# 2    1997-08-20    ep2                            /wiki/Weight_Gain_4000
# 3    1997-08-27    ep3                        /wiki/Volcano_(South_Park)
# 4    1997-09-03    ep4            /wiki/Big_Gay_Al%27s_Big_Gay_Boat_Ride
# 5    1997-09-10    ep5             /wiki/An_Elephant_Makes_Love_to_a_Pig
# ..          ...    ...                                               ...
# 315  2022-03-02  ep315                        /wiki/Back_to_the_Cold_War
# 316  2022-03-09  ep316                 /wiki/Help,_My_Teenager_Hates_Me!
# 317  2022-03-16  ep317  /wiki/Credigree_Weed_St._Patrick%27s_Day_Special
# 318  2022-06-01  ep318               /wiki/South_Park_The_Streaming_Wars
# 319  2022-07-13  ep319        /wiki/South_Park_The_Streaming_Wars_Part_2
#
#                                         title  \
# 1                  Cartman Gets an Anal Probe
# 2                            Weight Gain 4000
# 3                        Volcano (South Park)
# 4              Big Gay Al's Big Gay Boat Ride
# 5             An Elephant Makes Love to a Pig
# ..                                        ...
# 315                      Back to the Cold War
# 316               Help, My Teenager Hates Me!
# 317  Credigree Weed St. Patrick's Day Special
# 318             South Park The Streaming Wars
# 319      South Park The Streaming Wars Part 2
#
#                                               reflinks
# 1    [/wiki/South_Park_(season_16), /wiki/Tamale, /...
# 2    [/wiki/South_Park_(season_16), /wiki/Special:R...
# 3    [/wiki/South_Park_(season_16), /wiki/Special:R...
# 4    [/wiki/South_Park_(season_16), /wiki/Cripple_F...
# 5    [/wiki/South_Park_(season_16), /wiki/Special:R...
# ..                                                 ...
# 315  [/wiki/Battle_of_Trostianets, /wiki/South_Park...
# 316  [/wiki/South_Park_(season_16), /wiki/Special:R...
# 317  [/wiki/South_Park_(season_16), /wiki/Special:R...
# 318  [/wiki/The_SpongeBob_Movie:_Sponge_on_the_Run,...
# 319  [/wiki/The_SpongeBob_Movie:_Sponge_on_the_Run,...
#
# [319 rows x 5 columns]

# %%
totalurls = []
for key in epi.keys():
    #Try for key in epi
    urls = df["reflinks"][key]
    totalurls.extend(urls)
uniqueurls = list(set(totalurls))

# %%
complete='https://en.wikipedia.org/wiki/Tesla_Inc'
    #This is the complete URL
page=requests.get(complete)
soupy=BeautifulSoup(page.content)
identify='/wiki/Ticker_symbol'
func_call=urllist(soupy.find("table",class_="infobox vcard"))
func_call
#soupy
#soupy.find("a", class_ = "external text")
# Out:
# ['/wiki/Automotive_industry',
#  '/wiki/East_Asia',
#  '/wiki/Gigafactory_Texas',
#  '/wiki/United_States_dollar',
#  '/wiki/Asset',
#  '/wiki/Tesla_Model_3',
#  '/wiki/Tesla_Energy',
#  '/wiki/Chief_executive_officer',
#  '/wiki/S%26P_100',
#  '/wiki/S%26P_500',
#  '/wiki/Net_income',
#  '/wiki/Tesla_Megapack',
#  '/wiki/Robyn_Denholm',
#  '/wiki/International_Securities_Identification_Number',
#  '/wiki/Nasdaq',
#  '/wiki/Earnings_before_interest_and_taxes',
#  '/wiki/DeepScale',
#  '/wiki/Elon_Musk',
#  '/wiki/Tesla_Model_S',
#  '/wiki/Texas',
#  '/wiki/Middle_East',
#  '/wiki/San_Carlos,_California',
#  '/wiki/Nasdaq-100',
#  '/wiki/Europe',
#  '/wiki/Tesla_Grohmann_Automation',
#  '/wiki/Subsidiary',
#  '/wiki/Equity_(finance)',
#  '/wiki/Tesla_Powerpack',
#  '/wiki/Renewable_energy_industry',
#  '/wiki/Tesla_Powerwall',
#  '/wiki/Oceania',
#  '/wiki/Tesla_Model_X',
#  '/wiki/North_America',
#  '/wiki/Public_company',
#  '/wiki/Chairman',
#  '/wiki/Tesla_Model_Y',
#  '/wiki/Austin,_Texas',
#  '/wiki/Ticker_symbol',
#  '/wiki/Southeast_Asia']

# %%
testy='https://en.wikipedia.org'+'/wiki/Tesla_Inc'
testy_pg=requests.get(testy)
soupytest=BeautifulSoup(testy_pg.content)
urllist(soupytest.find("table",class_="infobox vcard"))
# Out:
# ['/wiki/Automotive_industry',
#  '/wiki/East_Asia',
#  '/wiki/Gigafactory_Texas',
#  '/wiki/United_States_dollar',
#  '/wiki/Asset',
#  '/wiki/Tesla_Model_3',
#  '/wiki/Tesla_Energy',
#  '/wiki/Chief_executive_officer',
#  '/wiki/S%26P_100',
#  '/wiki/S%26P_500',
#  '/wiki/Net_income',
#  '/wiki/Tesla_Megapack',
#  '/wiki/Robyn_Denholm',
#  '/wiki/International_Securities_Identification_Number',
#  '/wiki/Nasdaq',
#  '/wiki/Earnings_before_interest_and_taxes',
#  '/wiki/DeepScale',
#  '/wiki/Elon_Musk',
#  '/wiki/Tesla_Model_S',
#  '/wiki/Texas',
#  '/wiki/Middle_East',
#  '/wiki/San_Carlos,_California',
#  '/wiki/Nasdaq-100',
#  '/wiki/Europe',
#  '/wiki/Tesla_Grohmann_Automation',
#  '/wiki/Subsidiary',
#  '/wiki/Equity_(finance)',
#  '/wiki/Tesla_Powerpack',
#  '/wiki/Renewable_energy_industry',
#  '/wiki/Tesla_Powerwall',
#  '/wiki/Oceania',
#  '/wiki/Tesla_Model_X',
#  '/wiki/North_America',
#  '/wiki/Public_company',
#  '/wiki/Chairman',
#  '/wiki/Tesla_Model_Y',
#  '/wiki/Austin,_Texas',
#  '/wiki/Ticker_symbol',
#  '/wiki/Southeast_Asia']

# %%
companies_mentioned=[]
errors=[]
for url in uniqueurls:
    complete='https://en.wikipedia.org'+url
    #This is the complete URL
    page=requests.get(complete)
    soupy=BeautifulSoup(page.content)
    identify='/wiki/Ticker_symbol'
    try:
        func_call=urllist(soupy.find("table",class_="infobox vcard"))
        if identify in func_call:
            companies_mentioned.append(url)
    except:
        errors.append(url)
    time.sleep(0.1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\windows\temp/ipykernel_12056/3599962717.py in <module>
#       4     complete='https://en.wikipedia.org'+url
#       5     #This is the complete URL
# ----> 6     page=requests.get(complete)
#       7     soupy=BeautifulSoup(page.content)
#       8     identify='/wiki/Ticker_symbol'
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         # Trigger any extra validation we need to do.
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#     384             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1008         # Force connect early to allow us to validate the connection.
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#    1012         if not conn.is_verified:
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     409             context.load_default_certs()
#     410
# --> 411         self.sock = ssl_wrap_socket(
#     412             sock=conn,
#     413             keyfile=self.key_file,
#
# ~\anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     426
#     427     if send_sni:
# --> 428         ssl_sock = _ssl_wrap_socket_impl(
#     429             sock, context, tls_in_tls, server_hostname=server_hostname
#     430         )
#
# ~\anaconda3\lib\site-packages\urllib3\util\ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     470
#     471     if server_hostname:
# --> 472         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     473     else:
#     474         return ssl_context.wrap_socket(sock)
#
# ~\anaconda3\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     498         # SSLSocket class handles server_hostname encoding before it calls
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#     502             server_side=server_side,
#
# ~\anaconda3\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1038                         # non-blocking
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#    1042                 self.close()
#
# ~\anaconda3\lib\ssl.py in do_handshake(self, block)
#    1307             if timeout == 0.0 and block:
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#    1311             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
companies_mentioned
